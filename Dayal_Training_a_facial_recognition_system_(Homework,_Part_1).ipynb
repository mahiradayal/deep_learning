# %% [markdown]
# # A custom facial recognition system
#
# Once upon a time the NYT [built a system to recognize members of Congress](https://open.nytimes.com/how-the-new-york-times-uses-software-to-recognize-members-of-congress-29b46dd426c7). If they can do it, why not us?
#
# ## Obtaining the data
#
# To train a model to recognize members of Congress, we need *labeled pictures of members of Congress.* Luckily I spent a million years doing that for you!
#
# Since I haven't memorized everyone in Congress, I started with a [a list of members of legislators downloaded from GitHub](https://github.com/unitedstates/congress-legislators).

# %%
import pandas as pd
df = pd.read_csv("https://theunitedstates.io/congress-legislators/legislators-current.csv")
df.head()
# Out:
#   last_name first_name  ... icpsr_id    wikipedia_id
# 0     Brown    Sherrod  ...  29389.0   Sherrod Brown
# 1  Cantwell      Maria  ...  39310.0  Maria Cantwell
# 2    Cardin   Benjamin  ...  15408.0      Ben Cardin
# 3    Carper     Thomas  ...  15015.0      Tom Carper
# 4     Casey     Robert  ...  40703.0   Bob Casey Jr.
#
# [5 rows x 34 columns]

# %% [markdown]
# For each row, I combined their first and last name and used [Google Images Downloader](https://github.com/hardikvasa/google-images-download) to search Google Image Search for their name and download 30 images. Each image is stored in a folder named after the Congressperson.
#
# ```
# downloads/
# ├─ congressperson_xyz/
# │  ├─ 1.jpg
# │  ├─ 2.jpg
# │  ├─ 3.jpg
# ├─ congressperson_abc/
#    ├─ 1.jpg
#    ├─ 2.jpg
#    ├─ 3.jpg
# ...
# ```
# That ended up with about 8GB of images, which I then resized using [ImageMagick](https://imagemagick.org/) to a max size of 1080x1080. I guess some of the pictures were very high-res, that got us down to around 2GB.
#
# ### Just the faces, please
#
# Since human beings change their clothes each day, the *face* is the thing that allows us to tell different people apart. So I then ran each image through [MTCNN](https://github.com/ipazc/mtcnn) to cut out the faces and save them separately. So if we had an image with four faces in it, now we have four separate images instead.
#
# For a single member of Congress, all of the faces we found in all of the images of them are stored in a folder named after them.
#
# ```
# faces/
# ├─ congressperson_xyz/
# │  ├─ 1_face0.jpg
# │  ├─ 1_face1.jpg
# │  ├─ 2_face0.jpg
# │  ├─ 3_face0.jpg
# │  ├─ 3_face1.jpg
# │  ├─ 3_face2.jpg
# ├─ congressperson_abc/
#    ├─ 1_face0.jpg
#    ├─ 2_face0.jpg
#    ├─ 2_face1.jpg
#    ├─ 3_face0.jpg
# ...
# ```
#
# ## Pull in the data
#
# Start by downloading [faces.zip](https://drive.google.com/file/d/1-26HtaU6_PfJm-FizHSgJpUh_KRPO60S/view?usp=sharing), then uploading it to your Google Drive.
#
# Then, to import the data into this notebook, we'll need to connect Google Colab to Google Drive.

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# This code connects our Google Drive to the `gdrive` folder. The actual contents of your Google Drive will be in `grdrive/MyDrive`.
#
# Now we can copy `faces.zip` over and unzip it.

# %%
# Copy faces.zip into the current folder
# !cp /content/gdrive/MyDrive/faces.zip .

# Unzip it
# !unzip faces.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: faces/antonio_delgado/0_face_16.antonio_delgado_apfilejpg.jpg
#   inflating: faces/antonio_delgado/0_face_2.imkyeto0_400x400.jpg
#   inflating: faces/antonio_delgado/0_face_20.44920421_634056873657629_211051553304346624_n.jpg
#   inflating: faces/antonio_delgado/0_face_15.screen_shot_2018_07_18_at_9.23.24_am.0.png.jpg
#   inflating: faces/antonio_delgado/3_face_25.70b8abf6168d2345-1495034871082.jpg
#   inflating: faces/antonio_delgado/1_face_17.180511_antonio_delgado_0725-1145x700.jpg
#   inflating: faces/antonio_delgado/0_face_17.180511_antonio_delgado_0725-1145x700.jpg
#   inflating: faces/antonio_delgado/7_face_23.img_0105.jpeg
#   inflating: faces/antonio_delgado/1_face_13.delgado-e1541470468313-1024x640.jpg
#   inflating: faces/antonio_delgado/3_face_21.im-245737.jpg
#   inflating: faces/antonio_delgado/0_face_10.img_8096.jpg
#   inflating: faces/antonio_delgado/0_face_29.02faso-delgado1-articlelarge-v2.jpg
#    creating: faces/matt_gaetz/
#   inflating: faces/matt_gaetz/0_face_16.09dc-gaetz-mediumsquareat3x.jpg
#   inflating: faces/matt_gaetz/0_face_8.ap_20211670374488.jpg
#   inflating: faces/matt_gaetz/0_face_9.im-323138.jpg
#   inflating: faces/matt_gaetz/0_face_2.1188056017.jpg
#   inflating: faces/matt_gaetz/0_face_5.210414153348-02-matt-gaetz-0414-exlarge-169.jpg
#   inflating: faces/matt_gaetz/0_face_6.210406-think-matt-gaetz-se-1229p.jpg
#   inflating: faces/matt_gaetz/0_face_13.matt_gaetz%2c_official_portrait%2c_116th_congress.jpg
#   inflating: faces/matt_gaetz/2_face_19.comment-davidsonsorkin-mattgaetzgop.jpg
#   inflating: faces/matt_gaetz/0_face_19.comment-davidsonsorkin-mattgaetzgop.jpg
#   inflating: faces/matt_gaetz/1_face_21.210331-matt-gaetz-se-545p.jpg
#   inflating: faces/matt_gaetz/0_face_18.26dwc5o26bgcfgdpgx5wskspyy.jpg
#   inflating: faces/matt_gaetz/1_face_5.210414153348-02-matt-gaetz-0414-exlarge-169.jpg
#   inflating: faces/matt_gaetz/0_face_25.rep-matt-gaetz-0124-1617149062.jpg
#   inflating: faces/matt_gaetz/0_face_28.106863658-16176433812021-04-05t171805z_1830863151_rc2tpm9xroop_rtrmadp_0_usa-congress-gaetz.jpeg
#   inflating: faces/matt_gaetz/1_face_2.1188056017.jpg
#   inflating: faces/matt_gaetz/0_face_14._117849709_gettyimages-1230843995.jpg
#   inflating: faces/matt_gaetz/0_face_1.gaetz_investigation_82775.jpg
#   inflating: faces/matt_gaetz/1_face_23.matt-gaetz.jpg
#   inflating: faces/matt_gaetz/0_face_4.mattgaetz.jpg
#   inflating: faces/matt_gaetz/0_face_23.matt-gaetz.jpg
#   inflating: faces/matt_gaetz/2_face_2.1188056017.jpg
#   inflating: faces/matt_gaetz/0_face_29.merlin_184311090_35a9593e-795c-4408-ba36-e7567b2af169-articlelarge.jpg
#   inflating: faces/matt_gaetz/1_face_30.f266d919-0ce1-40e1-a318-c5274e8fbdba-epa_usa_congress_impeachment.jpg
#   inflating: faces/matt_gaetz/0_face_20.im-318485.jpg
#   inflating: faces/matt_gaetz/0_face_26.gettyimages-1231437520c.jpg
#   inflating: faces/matt_gaetz/0_face_21.210331-matt-gaetz-se-545p.jpg
#   inflating: faces/matt_gaetz/0_face_30.f266d919-0ce1-40e1-a318-c5274e8fbdba-epa_usa_congress_impeachment.jpg
#   inflating: faces/matt_gaetz/0_face_12.krcjlsjzabetdd7hq5w24w3pcy.jpeg
#   inflating: faces/matt_gaetz/0_face_24.f7772710-91a3-11eb-b7bf-0198c02e3fa7.jpg
#   inflating: faces/matt_gaetz/0_face_17.1617142010011.jpg
#   inflating: faces/matt_gaetz/0_face_7.1618447023306.jpg
#   inflating: faces/matt_gaetz/0_face_3.https%3a%2f%2fcdn.cnn.com%2fcnnnext%2fdam%2fassets%2f210331140547-01-matt-gaetz-file-2020.jpg
#   inflating: faces/matt_gaetz/0_face_22.matt-gaetz_hpmain_20210409-212029_16x9_992.jpg
#   inflating: faces/matt_gaetz/0_face_11.3000.jpeg
#   inflating: faces/matt_gaetz/0_face_27.5072.jpg
#   inflating: faces/matt_gaetz/0_face_15.merlin_185823405_8caf85b0-31d5-431e-8ef3-b6adc280009e-superjumbo.jpg
#   inflating: faces/matt_gaetz/1_face_19.comment-davidsonsorkin-mattgaetzgop.jpg
#   inflating: faces/matt_gaetz/1_face_14._117849709_gettyimages-1230843995.jpg
#   inflating: faces/matt_gaetz/0_face_10.4000.jpg
#   inflating: faces/matt_gaetz/1_face_25.rep-matt-gaetz-0124-1617149062.jpg
#   inflating: faces/matt_gaetz/1_face_13.matt_gaetz%2c_official_portrait%2c_116th_congress.jpg
#    creating: faces/jahana_hayes/
#   inflating: faces/jahana_hayes/1_face_19.kbbnvpei6rboplpqmtszjm7mz4.jpg
#   inflating: faces/jahana_hayes/8_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/4_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/2_face_2.dwuorcfvyaa1fdi.jpg
#   inflating: faces/jahana_hayes/1_face_24.36ecddf2-825f-40db-a350-2ab6934fd606_1920x1080.jpg
#   inflating: faces/jahana_hayes/2_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/4_face_4.180817-jahana-hayes-campaign-ew-126p_437ce5f5aee898a7feb3e64d0b772684.jpg
#   inflating: faces/jahana_hayes/7_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/7_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/2_face_10.rts24v3e-1024x697.jpg
#   inflating: faces/jahana_hayes/2_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/1_face_8.ckelf5km2netfdtlkxyiiw4ooi.jpg
#   inflating: faces/jahana_hayes/9_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/0_face_22.jahana-hayes-blue-wave.jpg
#   inflating: faces/jahana_hayes/4_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/1_face_10.rts24v3e-1024x697.jpg
#   inflating: faces/jahana_hayes/3_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/6_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/1_face_2.dwuorcfvyaa1fdi.jpg
#   inflating: faces/jahana_hayes/12_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/2_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/6_face_18.2087c485-3489-4986-94bb-e2f44514f3ae_1920x1080.jpg
#   inflating: faces/jahana_hayes/0_face_10.rts24v3e-1024x697.jpg
#   inflating: faces/jahana_hayes/0_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/6_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/4_face_19.kbbnvpei6rboplpqmtszjm7mz4.jpg
#   inflating: faces/jahana_hayes/5_face_2.dwuorcfvyaa1fdi.jpg
#   inflating: faces/jahana_hayes/0_face_27..jpg
#   inflating: faces/jahana_hayes/10_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/3_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/2_face_18.2087c485-3489-4986-94bb-e2f44514f3ae_1920x1080.jpg
#   inflating: faces/jahana_hayes/8_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/0_face_6.ets2xz62_400x400.jpg
#   inflating: faces/jahana_hayes/5_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/1_face_3.jahanahayes_fbjh_180703.jpg
#   inflating: faces/jahana_hayes/0_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/1_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/2_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/0_face_26.ssx6m3w-asset-mezzanine-16x9-9sp2mmw.jpg
#   inflating: faces/jahana_hayes/0_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/4_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/0_face_21.201014-jahana_hayes-mc-1406_a4c693362505a6bcbbd7430a82899b1a.fit-760w.jpg
#   inflating: faces/jahana_hayes/1_face_17.ameliapoor_jahanahayes_sq.jpg
#   inflating: faces/jahana_hayes/4_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/2_face_3.jahanahayes_fbjh_180703.jpg
#   inflating: faces/jahana_hayes/5_face_18.2087c485-3489-4986-94bb-e2f44514f3ae_1920x1080.jpg
#   inflating: faces/jahana_hayes/0_face_18.2087c485-3489-4986-94bb-e2f44514f3ae_1920x1080.jpg
#   inflating: faces/jahana_hayes/0_face_7.attachment.jpg
#   inflating: faces/jahana_hayes/0_face_25.k8yit3q1k6mwe4sf.jpg
#   inflating: faces/jahana_hayes/5_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/0_face_29.impeachment_markup029_121119.jpg
#   inflating: faces/jahana_hayes/1_face_27..jpg
#   inflating: faces/jahana_hayes/7_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/0_face_2.dwuorcfvyaa1fdi.jpg
#   inflating: faces/jahana_hayes/0_face_8.ckelf5km2netfdtlkxyiiw4ooi.jpg
#   inflating: faces/jahana_hayes/1_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/11_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/1_face_4.180817-jahana-hayes-campaign-ew-126p_437ce5f5aee898a7feb3e64d0b772684.jpg
#   inflating: faces/jahana_hayes/0_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/9_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/0_face_12.h001081.jpg
#   inflating: faces/jahana_hayes/0_face_4.180817-jahana-hayes-campaign-ew-126p_437ce5f5aee898a7feb3e64d0b772684.jpg
#   inflating: faces/jahana_hayes/1_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/3_face_4.180817-jahana-hayes-campaign-ew-126p_437ce5f5aee898a7feb3e64d0b772684.jpg
#   inflating: faces/jahana_hayes/7_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/1_face_9.merlin_179428917_abd0aba6-2ab0-4f30-a633-df27aaaefa37-mobilemasterat3x.jpg
#   inflating: faces/jahana_hayes/3_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/1_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/2_face_5.hayes-two.jpg
#   inflating: faces/jahana_hayes/0_face_9.merlin_179428917_abd0aba6-2ab0-4f30-a633-df27aaaefa37-mobilemasterat3x.jpg
#   inflating: faces/jahana_hayes/1_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/2_face_19.kbbnvpei6rboplpqmtszjm7mz4.jpg
#   inflating: faces/jahana_hayes/4_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/3_face_5.hayes-two.jpg
#   inflating: faces/jahana_hayes/3_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/6_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/8_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/5_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/6_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/1_face_18.2087c485-3489-4986-94bb-e2f44514f3ae_1920x1080.jpg
#   inflating: faces/jahana_hayes/2_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/1_face_28.newtown5.jpg
#   inflating: faces/jahana_hayes/0_face_1.jh_official%20photo.jpg
#   inflating: faces/jahana_hayes/3_face_27..jpg
#   inflating: faces/jahana_hayes/4_face_5.hayes-two.jpg
#   inflating: faces/jahana_hayes/3_face_18.2087c485-3489-4986-94bb-e2f44514f3ae_1920x1080.jpg
#   inflating: faces/jahana_hayes/5_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/0_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/3_face_2.dwuorcfvyaa1fdi.jpg
#   inflating: faces/jahana_hayes/1_face_29.impeachment_markup029_121119.jpg
#   inflating: faces/jahana_hayes/4_face_18.2087c485-3489-4986-94bb-e2f44514f3ae_1920x1080.jpg
#   inflating: faces/jahana_hayes/6_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/3_face_19.kbbnvpei6rboplpqmtszjm7mz4.jpg
#   inflating: faces/jahana_hayes/0_face_5.hayes-two.jpg
#   inflating: faces/jahana_hayes/2_face_9.merlin_179428917_abd0aba6-2ab0-4f30-a633-df27aaaefa37-mobilemasterat3x.jpg
#   inflating: faces/jahana_hayes/0_face_19.kbbnvpei6rboplpqmtszjm7mz4.jpg
#   inflating: faces/jahana_hayes/5_face_5.hayes-two.jpg
#   inflating: faces/jahana_hayes/0_face_20.jahana-hayes-newly-sworn-in-pu-20190103-720_720_540_99_sha-100.jpg
#   inflating: faces/jahana_hayes/5_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/7_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/7_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/2_face_4.180817-jahana-hayes-campaign-ew-126p_437ce5f5aee898a7feb3e64d0b772684.jpg
#   inflating: faces/jahana_hayes/2_face_27..jpg
#   inflating: faces/jahana_hayes/2_face_14.merlin_142371429_a72b9dcd-333d-4b5e-9c66-a764056171ac-superjumbo.jpg
#   inflating: faces/jahana_hayes/0_face_24.36ecddf2-825f-40db-a350-2ab6934fd606_1920x1080.jpg
#   inflating: faces/jahana_hayes/4_face_27..jpg
#   inflating: faces/jahana_hayes/1_face_5.hayes-two.jpg
#   inflating: faces/jahana_hayes/4_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/9_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/0_face_23.jahana_hayes_primary_night_-2.jpg
#   inflating: faces/jahana_hayes/6_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/5_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/0_face_17.ameliapoor_jahanahayes_sq.jpg
#   inflating: faces/jahana_hayes/0_face_15.nea-member-jahana-hayes-1-e1461850798394.jpg
#   inflating: faces/jahana_hayes/13_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#   inflating: faces/jahana_hayes/4_face_2.dwuorcfvyaa1fdi.jpg
#   inflating: faces/jahana_hayes/3_face_11.jaharact.jpg
#   inflating: faces/jahana_hayes/5_face_4.180817-jahana-hayes-campaign-ew-126p_437ce5f5aee898a7feb3e64d0b772684.jpg
#   inflating: faces/jahana_hayes/3_face_30.hayes_selects-1.jpg
#   inflating: faces/jahana_hayes/0_face_3.jahanahayes_fbjh_180703.jpg
#   inflating: faces/jahana_hayes/0_face_16.scsu_16_jahanahayes-5643.jpg
#   inflating: faces/jahana_hayes/8_face_13.105559117-1541605779772gettyimages-527764622.jpeg
#    creating: faces/amy_klobuchar/
#   inflating: faces/amy_klobuchar/1_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/5_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/4_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/0_face_17.20180601_ajk_family-5849-3.jpg
#   inflating: faces/amy_klobuchar/0_face_27.amy-klobuchar-2009.jpg
#   inflating: faces/amy_klobuchar/6_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/1_face_29.senator-amy-klobuchar.jpg
#   inflating: faces/amy_klobuchar/1_face_21.amy_klobuchar_collage_1998_2006_2019.jpeg
#   inflating: faces/amy_klobuchar/0_face_23.klobucharfeatured.jpg
#   inflating: faces/amy_klobuchar/8_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/2_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/10_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/9_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/0_face_19.b63465-20100803-rose-klobuchar.jpg
#   inflating: faces/amy_klobuchar/1_face_17.20180601_ajk_family-5849-3.jpg
#   inflating: faces/amy_klobuchar/0_face_4.amy-klobuchar-2007.jpg
#   inflating: faces/amy_klobuchar/0_face_24.amyklobuchar110720_940.jpg
#   inflating: faces/amy_klobuchar/3_face_21.amy_klobuchar_collage_1998_2006_2019.jpeg
#   inflating: faces/amy_klobuchar/2_face_30.ap_18270510166509-e1597246941995-1000x660.jpg
#   inflating: faces/amy_klobuchar/1_face_16.klobuchar-husband-gty-aa-200324_hpmain_16x9_992.jpg
#   inflating: faces/amy_klobuchar/0_face_26.190331_tw_klobuchar_hpmain_16x9_992.jpg
#   inflating: faces/amy_klobuchar/0_face_13._112973706_mediaitem112973705.jpg
#   inflating: faces/amy_klobuchar/0_face_7..jpg
#   inflating: faces/amy_klobuchar/1_face_30.ap_18270510166509-e1597246941995-1000x660.jpg
#   inflating: faces/amy_klobuchar/0_face_16.klobuchar-husband-gty-aa-200324_hpmain_16x9_992.jpg
#   inflating: faces/amy_klobuchar/0_face_20.10-klobuchar-candidatepage-videosixteenbyninejumbo1600.jpg
#   inflating: faces/amy_klobuchar/3_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/0_face_21.amy_klobuchar_collage_1998_2006_2019.jpeg
#   inflating: faces/amy_klobuchar/2_face_17.20180601_ajk_family-5849-3.jpg
#   inflating: faces/amy_klobuchar/0_face_9.10-klobuchar-candidatepage-superjumbo.jpg
#   inflating: faces/amy_klobuchar/7_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/0_face_28.79731282-95f2-443e-8d7c-2c46399ed8b0-0103-klobuchar-005.jpg
#   inflating: faces/amy_klobuchar/0_face_25.ows_ee72db77_a4d8_4372_bc9c_c1d7dd578bc4.jpg
#   inflating: faces/amy_klobuchar/1_face_19.b63465-20100803-rose-klobuchar.jpg
#   inflating: faces/amy_klobuchar/1_face_13._112973706_mediaitem112973705.jpg
#   inflating: faces/amy_klobuchar/0_face_3.im-159653.jpg
#   inflating: faces/amy_klobuchar/0_face_15.klobucharamy_abofeb19_0.jpg
#   inflating: faces/amy_klobuchar/1_face_28.79731282-95f2-443e-8d7c-2c46399ed8b0-0103-klobuchar-005.jpg
#   inflating: faces/amy_klobuchar/0_face_22.190618142957-01-amy-klobuchar-gallery-restricted-live-video.jpg
#   inflating: faces/amy_klobuchar/2_face_14.amy-klobuchar.jpg
#   inflating: faces/amy_klobuchar/0_face_14.amy-klobuchar.jpg
#   inflating: faces/amy_klobuchar/1_face_14.amy-klobuchar.jpg
#   inflating: faces/amy_klobuchar/2_face_21.amy_klobuchar_collage_1998_2006_2019.jpeg
#   inflating: faces/amy_klobuchar/0_face_29.senator-amy-klobuchar.jpg
#   inflating: faces/amy_klobuchar/0_face_8.5f889e160e33e.image.jpg
#   inflating: faces/amy_klobuchar/0_face_2.amy_klobuchar%2c_official_portrait%2c_113th_congress.jpg
#   inflating: faces/amy_klobuchar/3_face_30.ap_18270510166509-e1597246941995-1000x660.jpg
#   inflating: faces/amy_klobuchar/2_face_19.b63465-20100803-rose-klobuchar.jpg
#   inflating: faces/amy_klobuchar/0_face_10.photo-by-ethan-millergetty-images.jpg
#   inflating: faces/amy_klobuchar/0_face_5.200210201517-01-amy-klobuchar-lead-image-center.jpg
#   inflating: faces/amy_klobuchar/0_face_30.ap_18270510166509-e1597246941995-1000x660.jpg
#   inflating: faces/amy_klobuchar/0_face_1.sugrph6d.jpg
#   inflating: faces/amy_klobuchar/0_face_18.190807_vod_orig_klobuchar_profile_hpmain_16x9_992.jpg
#   inflating: faces/amy_klobuchar/0_face_6.amy%20klobuchar%20allegations.jpg
#   inflating: faces/amy_klobuchar/0_face_11.200208-amy-klobuchar-al-1446_d7928bba9f6d83cd553188ba724be8ba.jpg
#   inflating: faces/amy_klobuchar/0_face_12.4241.jpg
#    creating: faces/eric_crawford/
#   inflating: faces/eric_crawford/2_face_25.hqdefault.jpg
#   inflating: faces/eric_crawford/0_face_25.hqdefault.jpg
#   inflating: faces/eric_crawford/0_face_23.647214e3235d0387341ce7f4dfc8c901.jpeg
#   inflating: faces/eric_crawford/0_face_20.erickeithcrawford-1.jpg
#   inflating: faces/eric_crawford/0_face_30.2b67b5b255f2f0fc4b8dc87babc3464e.jpeg
#   inflating: faces/eric_crawford/0_face_6.90.jpg
#   inflating: faces/eric_crawford/2_face_10.eric+crawford+b9mrhsbbyndm.jpg
#   inflating: faces/eric_crawford/1_face_23.647214e3235d0387341ce7f4dfc8c901.jpeg
#   inflating: faces/eric_crawford/0_face_22._mg_1214.jpg
#   inflating: faces/eric_crawford/0_face_1.eric_crawford_mbkb_18_03.jpg
#   inflating: faces/eric_crawford/1_face_8.ai-hczis.jpg
#   inflating: faces/eric_crawford/0_face_18.nba_g_crawford_1296x729.jpg
#   inflating: faces/eric_crawford/0_face_7.1821245432-crawford-eric-hr.jpg
#   inflating: faces/eric_crawford/0_face_24.1516952647389.jpg
#   inflating: faces/eric_crawford/2_face_26.hc-xpm-2012-04-25-hc-hartford-crawford-arrest-0426-20120425.jpg
#   inflating: faces/eric_crawford/0_face_9.23028879_20210311_ericcrawford_2257.jpg
#   inflating: faces/eric_crawford/0_face_27.crawford_eric_15_vs_sbu_1560.jpg
#   inflating: faces/eric_crawford/0_face_11.blo-19-3-crawforde-214x300.jpg
#   inflating: faces/eric_crawford/0_face_4.c001087.jpg
#   inflating: faces/eric_crawford/0_face_21.eric-crawford.jpg
#   inflating: faces/eric_crawford/0_face_12.msoc_web_0008_eric_crawford_08162018_0001_jpg.jpg
#   inflating: faces/eric_crawford/1_face_26.hc-xpm-2012-04-25-hc-hartford-crawford-arrest-0426-20120425.jpg
#   inflating: faces/eric_crawford/0_face_16.eric.jpeg
#   inflating: faces/eric_crawford/0_face_26.hc-xpm-2012-04-25-hc-hartford-crawford-arrest-0426-20120425.jpg
#   inflating: faces/eric_crawford/0_face_15.eric-crawford-reckless-driving-to-endanger.jpg
#   inflating: faces/eric_crawford/3_face_25.hqdefault.jpg
#   inflating: faces/eric_crawford/1_face_10.eric+crawford+b9mrhsbbyndm.jpg
#   inflating: faces/eric_crawford/0_face_13.ericcrawford.jpeg.256x256_q100_crop-smart.jpg
#   inflating: faces/eric_crawford/2_face_17.emf858oxuae9tom.jpg
#   inflating: faces/eric_crawford/0_face_8.ai-hczis.jpg
#   inflating: faces/eric_crawford/0_face_14.412400-200px.jpeg
#   inflating: faces/eric_crawford/4_face_26.hc-xpm-2012-04-25-hc-hartford-crawford-arrest-0426-20120425.jpg
#   inflating: faces/eric_crawford/0_face_28.eric-crawford.jpg
#   inflating: faces/eric_crawford/1_face_25.hqdefault.jpg
#   inflating: faces/eric_crawford/1_face_18.nba_g_crawford_1296x729.jpg
#   inflating: faces/eric_crawford/1_face_17.emf858oxuae9tom.jpg
#   inflating: faces/eric_crawford/0_face_5.i.jpg
#   inflating: faces/eric_crawford/1_face_9.23028879_20210311_ericcrawford_2257.jpg
#   inflating: faces/eric_crawford/3_face_26.hc-xpm-2012-04-25-hc-hartford-crawford-arrest-0426-20120425.jpg
#   inflating: faces/eric_crawford/1_face_29.57bb1b27373a3f6343287fb641bd8384.jpg
#   inflating: faces/eric_crawford/0_face_2.23028879_20210311_ericcrawford_2281.jpg
#   inflating: faces/eric_crawford/0_face_10.eric+crawford+b9mrhsbbyndm.jpg
#   inflating: faces/eric_crawford/0_face_3.5c07c87ee5466.image.jpg
#   inflating: faces/eric_crawford/0_face_17.emf858oxuae9tom.jpg
#   inflating: faces/eric_crawford/0_face_29.57bb1b27373a3f6343287fb641bd8384.jpg
#    creating: faces/nicole_malliotakis/
#   inflating: faces/nicole_malliotakis/0_face_28.nicolemalliotakis-1.jpg
#   inflating: faces/nicole_malliotakis/5_face_19.malliotakis_fearless_girl_nmalliotakis.jpg
#   inflating: faces/nicole_malliotakis/1_face_20.todd04242018341113-copy-scaled.jpg
#   inflating: faces/nicole_malliotakis/0_face_18.nicole-001jpg-fcd0e00fa7c10bc8.jpg
#   inflating: faces/nicole_malliotakis/1_face_3.ap-max-rose-nicole-malliotakis-sidebysidejpg.jpg
#   inflating: faces/nicole_malliotakis/1_face_5.politics-nicole-malliotakis-donald-trump-white-house.jpg
#   inflating: faces/nicole_malliotakis/1_face_4.190125-nicole-malliotakis-feature-image.jpg
#   inflating: faces/nicole_malliotakis/4_face_5.politics-nicole-malliotakis-donald-trump-white-house.jpg
#   inflating: faces/nicole_malliotakis/0_face_23.malliotakis-immigrant-experience.jpg
#   inflating: faces/nicole_malliotakis/0_face_25.105418355_1139153293137617_576271328399206601_n.jpg
#   inflating: faces/nicole_malliotakis/4_face_19.malliotakis_fearless_girl_nmalliotakis.jpg
#   inflating: faces/nicole_malliotakis/3_face_25.105418355_1139153293137617_576271328399206601_n.jpg
#   inflating: faces/nicole_malliotakis/4_face_16.nicole.jpg
#   inflating: faces/nicole_malliotakis/0_face_20.todd04242018341113-copy-scaled.jpg
#   inflating: faces/nicole_malliotakis/0_face_8.cnm%20sia.jpg
#   inflating: faces/nicole_malliotakis/2_face_16.nicole.jpg
#   inflating: faces/nicole_malliotakis/0_face_4.190125-nicole-malliotakis-feature-image.jpg
#   inflating: faces/nicole_malliotakis/0_face_15.nicole-malliotakis-and-rudy-giuliani.jpg
#   inflating: faces/nicole_malliotakis/5_face_16.nicole.jpg
#   inflating: faces/nicole_malliotakis/0_face_7.7l2phukd6zhs5fe6pgal5bsoga.jpg
#   inflating: faces/nicole_malliotakis/2_face_15.nicole-malliotakis-and-rudy-giuliani.jpg
#   inflating: faces/nicole_malliotakis/0_face_27.maxroseandnicolemalliotakis-2.jpg
#   inflating: faces/nicole_malliotakis/4_face_25.105418355_1139153293137617_576271328399206601_n.jpg
#   inflating: faces/nicole_malliotakis/3_face_5.politics-nicole-malliotakis-donald-trump-white-house.jpg
#   inflating: faces/nicole_malliotakis/1_face_9.bn-vd712_nymall_gr_20170917170353.jpg
#   inflating: faces/nicole_malliotakis/0_face_1.1200px-congresswoman_nicole_malliotakis.jpg
#   inflating: faces/nicole_malliotakis/1_face_18.nicole-001jpg-fcd0e00fa7c10bc8.jpg
#   inflating: faces/nicole_malliotakis/1_face_27.maxroseandnicolemalliotakis-2.jpg
#   inflating: faces/nicole_malliotakis/2_face_5.politics-nicole-malliotakis-donald-trump-white-house.jpg
#   inflating: faces/nicole_malliotakis/0_face_10.cgd11_nicole-malliotakis_photo.jpg
#   inflating: faces/nicole_malliotakis/0_face_17.malliotakisnicole_ny11.jpg
#   inflating: faces/nicole_malliotakis/1_face_29.021220_nyc_donaldtrumpnicolemalliotakispng.jpg
#   inflating: faces/nicole_malliotakis/0_face_19.malliotakis_fearless_girl_nmalliotakis.jpg
#   inflating: faces/nicole_malliotakis/2_face_13.politics-nicole-malliotakis-ivanka-trump-kimberly-guilfoyle.jpg
#   inflating: faces/nicole_malliotakis/0_face_6.ulbhffwx_400x400.jpg
#   inflating: faces/nicole_malliotakis/1_face_16.nicole.jpg
#   inflating: faces/nicole_malliotakis/1_face_15.nicole-malliotakis-and-rudy-giuliani.jpg
#   inflating: faces/nicole_malliotakis/1_face_25.105418355_1139153293137617_576271328399206601_n.jpg
#   inflating: faces/nicole_malliotakis/1_face_21.max_nicole_2.0.7.jpg
#   inflating: faces/nicole_malliotakis/0_face_26.gtvnadwnibdtfagfageacqikbe.jpg
#   inflating: faces/nicole_malliotakis/0_face_2.00mallioqa-superjumbo.jpg
#   inflating: faces/nicole_malliotakis/2_face_25.105418355_1139153293137617_576271328399206601_n.jpg
#   inflating: faces/nicole_malliotakis/0_face_24..jpg
#   inflating: faces/nicole_malliotakis/3_face_19.malliotakis_fearless_girl_nmalliotakis.jpg
#   inflating: faces/nicole_malliotakis/0_face_3.ap-max-rose-nicole-malliotakis-sidebysidejpg.jpg
#   inflating: faces/nicole_malliotakis/0_face_29.021220_nyc_donaldtrumpnicolemalliotakispng.jpg
#   inflating: faces/nicole_malliotakis/2_face_19.malliotakis_fearless_girl_nmalliotakis.jpg
#   inflating: faces/nicole_malliotakis/0_face_11.800.jpeg
#   inflating: faces/nicole_malliotakis/1_face_26.gtvnadwnibdtfagfageacqikbe.jpg
#   inflating: faces/nicole_malliotakis/0_face_14.mari.jpg
#   inflating: faces/nicole_malliotakis/0_face_30.m000317.jpg
#   inflating: faces/nicole_malliotakis/0_face_13.politics-nicole-malliotakis-ivanka-trump-kimberly-guilfoyle.jpg
#   inflating: faces/nicole_malliotakis/1_face_22.pjimage-4.jpg
#   inflating: faces/nicole_malliotakis/2_face_18.nicole-001jpg-fcd0e00fa7c10bc8.jpg
#   inflating: faces/nicole_malliotakis/0_face_21.max_nicole_2.0.7.jpg
#   inflating: faces/nicole_malliotakis/0_face_16.nicole.jpg
#   inflating: faces/nicole_malliotakis/1_face_24..jpg
#   inflating: faces/nicole_malliotakis/0_face_12.nicole-malliotakis-1.jpg
#   inflating: faces/nicole_malliotakis/1_face_11.800.jpeg
#   inflating: faces/nicole_malliotakis/1_face_7.7l2phukd6zhs5fe6pgal5bsoga.jpg
#   inflating: faces/nicole_malliotakis/0_face_5.politics-nicole-malliotakis-donald-trump-white-house.jpg
#   inflating: faces/nicole_malliotakis/3_face_16.nicole.jpg
#   inflating: faces/nicole_malliotakis/2_face_11.800.jpeg
#   inflating: faces/nicole_malliotakis/0_face_22.pjimage-4.jpg
#   inflating: faces/nicole_malliotakis/3_face_11.800.jpeg
#   inflating: faces/nicole_malliotakis/6_face_19.malliotakis_fearless_girl_nmalliotakis.jpg
#   inflating: faces/nicole_malliotakis/1_face_19.malliotakis_fearless_girl_nmalliotakis.jpg
#   inflating: faces/nicole_malliotakis/1_face_13.politics-nicole-malliotakis-ivanka-trump-kimberly-guilfoyle.jpg
#   inflating: faces/nicole_malliotakis/0_face_9.bn-vd712_nymall_gr_20170917170353.jpg
#    creating: faces/dwight_evans/
#   inflating: faces/dwight_evans/0_face_15.115_rp_pa_2_evans_dwight_200.jpg
#   inflating: faces/dwight_evans/0_face_18.t3ukpmdfjui6thjkkmujgwsufu.jpg
#   inflating: faces/dwight_evans/0_face_9.dwightevans.jpg
#   inflating: faces/dwight_evans/0_face_8.dwight_evans_20180504_sl_1.jpg
#   inflating: faces/dwight_evans/0_face_10.sx7i6kbmnndpfolc4ltjhnnt4q.jpg
#   inflating: faces/dwight_evans/0_face_26.rice%20jim%2052.2009.2_grp_hofuseonly.jpg
#   inflating: faces/dwight_evans/2_face_26.rice%20jim%2052.2009.2_grp_hofuseonly.jpg
#   inflating: faces/dwight_evans/0_face_30.evan9285.jpg
#   inflating: faces/dwight_evans/1_face_26.rice%20jim%2052.2009.2_grp_hofuseonly.jpg
#   inflating: faces/dwight_evans/0_face_22.dwight-evans.jpg
#   inflating: faces/dwight_evans/0_face_25.image020117220539-000.jpg
#   inflating: faces/dwight_evans/1_face_19.een1u7exoaym_ql.jpg
#   inflating: faces/dwight_evans/0_face_1.dwight_evans_official_portrait.jpg
#   inflating: faces/dwight_evans/1_face_7.gettyimages-83249997.jpg
#   inflating: faces/dwight_evans/2_face_6.evans-meets-vets.jpg
#   inflating: faces/dwight_evans/1_face_18.t3ukpmdfjui6thjkkmujgwsufu.jpg
#   inflating: faces/dwight_evans/1_face_29.014-dwightevansmural-final.original.jpg
#   inflating: faces/dwight_evans/0_face_16.photo-visit-capitol-dome-web02.jpg
#   inflating: faces/dwight_evans/1_face_23.fattah-evans.jpg
#   inflating: faces/dwight_evans/0_face_17.gettyimages-1132361579-e1575407547606.jpg
#   inflating: faces/dwight_evans/1_face_27.gettyimages-963144748-1024x683.jpg
#   inflating: faces/dwight_evans/0_face_27.gettyimages-963144748-1024x683.jpg
#   inflating: faces/dwight_evans/0_face_23.fattah-evans.jpg
#   inflating: faces/dwight_evans/0_face_19.een1u7exoaym_ql.jpg
#   inflating: faces/dwight_evans/0_face_4.dwight-evans-1024x685.jpg
#   inflating: faces/dwight_evans/1_face_6.evans-meets-vets.jpg
#   inflating: faces/dwight_evans/1_face_21.ed-rendell-and-dwight-evans-791x400.jpg
#   inflating: faces/dwight_evans/0_face_24.outsiders_deweyevans-1024x683.jpg
#   inflating: faces/dwight_evans/0_face_28.hskqohapybfc5dlqhmqlhmalxq.jpg
#   inflating: faces/dwight_evans/0_face_29.014-dwightevansmural-final.original.jpg
#   inflating: faces/dwight_evans/0_face_21.ed-rendell-and-dwight-evans-791x400.jpg
#   inflating: faces/dwight_evans/0_face_20.boston-red-sox-dwight-evans-september-26-1988-sports-illustrated-cover.jpg
#   inflating: faces/dwight_evans/0_face_14._5jskqhf.jpg
#   inflating: faces/dwight_evans/0_face_12.1073503696.jpg.0.jpg
#   inflating: faces/dwight_evans/0_face_2.412677-200px.jpeg
#   inflating: faces/dwight_evans/0_face_6.evans-meets-vets.jpg
#   inflating: faces/dwight_evans/0_face_7.gettyimages-83249997.jpg
#   inflating: faces/dwight_evans/0_face_11.gettyimages-660639218.jpg
#   inflating: faces/dwight_evans/0_face_13.dwight-evans*1200xx2867-1613-0-593.jpg
#   inflating: faces/dwight_evans/0_face_5.269.jpg
#   inflating: faces/dwight_evans/0_face_3.https%3a%2f%2fspecials-images.forbesimg.com%2fdam%2fimageserve%2ffd6fc73b48614229ac159ad08c8b990f%2f960x0.jpg%3ffit%3dscale.jpg
#    creating: faces/sanford_bishop/
#   inflating: faces/sanford_bishop/1_face_28.607b283c7d108.image.jpg
#   inflating: faces/sanford_bishop/1_face_30.ic3x4ymx6nar3ngf44b4lrirhq.jpg
#   inflating: faces/sanford_bishop/0_face_8.hxaauzh6xzgg5epbppkcowgg6q.jpg
#   inflating: faces/sanford_bishop/0_face_23.c2d6b2a4-1bad-49f5-86d1-f6c8fb73846b_1920x1080.jpg
#   inflating: faces/sanford_bishop/0_face_24.82e97da1-b82e-4a1e-9301-08c64c483a89-large16x9_thumbnail_img_1809_1.jpg
#   inflating: faces/sanford_bishop/2_face_19.56795507_2384927674874541_8541956933970558976_o.jpg
#   inflating: faces/sanford_bishop/0_face_28.607b283c7d108.image.jpg
#   inflating: faces/sanford_bishop/4_face_13.05georgia-cnd-jumbo.jpg
#   inflating: faces/sanford_bishop/0_face_2.rjl32rw6zxkszb84av5z_400x400.jpeg
#   inflating: faces/sanford_bishop/1_face_29.64hpmnxskfe5zlbgxphi6pwezu.jpg
#   inflating: faces/sanford_bishop/1_face_11.20200731-sanfordbishop-gty-773.jpg
#   inflating: faces/sanford_bishop/5_face_19.56795507_2384927674874541_8541956933970558976_o.jpg
#   inflating: faces/sanford_bishop/0_face_20.8e60fcc6-bcda-44bc-8d65-c0fdc1abacd8-large16x9_gettyimages688276704.jpg
#   inflating: faces/sanford_bishop/0_face_11.20200731-sanfordbishop-gty-773.jpg
#   inflating: faces/sanford_bishop/0_face_7.b000490.jpg
#   inflating: faces/sanford_bishop/1_face_24.82e97da1-b82e-4a1e-9301-08c64c483a89-large16x9_thumbnail_img_1809_1.jpg
#   inflating: faces/sanford_bishop/0_face_27.maxresdefault.jpg
#   inflating: faces/sanford_bishop/2_face_13.05georgia-cnd-jumbo.jpg
#   inflating: faces/sanford_bishop/0_face_30.ic3x4ymx6nar3ngf44b4lrirhq.jpg
#   inflating: faces/sanford_bishop/0_face_13.05georgia-cnd-jumbo.jpg
#   inflating: faces/sanford_bishop/1_face_27.maxresdefault.jpg
#   inflating: faces/sanford_bishop/0_face_25.bishopsanford_112917gn_lead.jpg
#   inflating: faces/sanford_bishop/2_face_21.4fx7czx7h5k7ve6ltprlv3xrda.jpg
#   inflating: faces/sanford_bishop/0_face_1.sanford_bishop.jpg
#   inflating: faces/sanford_bishop/1_face_17.4cr7wphxxjfvphx6jvim5vnnqm.jpg
#   inflating: faces/sanford_bishop/1_face_14.ifbqu2vh43kezqwyc2v6npqw2e.jpg
#   inflating: faces/sanford_bishop/3_face_5.img_0338.jpg
#   inflating: faces/sanford_bishop/0_face_5.img_0338.jpg
#   inflating: faces/sanford_bishop/3_face_13.05georgia-cnd-jumbo.jpg
#   inflating: faces/sanford_bishop/1_face_20.8e60fcc6-bcda-44bc-8d65-c0fdc1abacd8-large16x9_gettyimages688276704.jpg
#   inflating: faces/sanford_bishop/0_face_22.prblackhistorymonth2016.jpg
#   inflating: faces/sanford_bishop/2_face_18.607b283172993.image.jpg
#   inflating: faces/sanford_bishop/1_face_25.bishopsanford_112917gn_lead.jpg
#   inflating: faces/sanford_bishop/2_face_5.img_0338.jpg
#   inflating: faces/sanford_bishop/0_face_18.607b283172993.image.jpg
#   inflating: faces/sanford_bishop/0_face_3.sanford_d._bishop_jr.jpg
#   inflating: faces/sanford_bishop/0_face_10.pp6wx7skfjg3bnxlnebkqqfyke.png.jpg
#   inflating: faces/sanford_bishop/0_face_14.ifbqu2vh43kezqwyc2v6npqw2e.jpg
#   inflating: faces/sanford_bishop/0_face_17.4cr7wphxxjfvphx6jvim5vnnqm.jpg
#   inflating: faces/sanford_bishop/0_face_21.4fx7czx7h5k7ve6ltprlv3xrda.jpg
#   inflating: faces/sanford_bishop/6_face_19.56795507_2384927674874541_8541956933970558976_o.jpg
#   inflating: faces/sanford_bishop/0_face_29.64hpmnxskfe5zlbgxphi6pwezu.jpg
#   inflating: faces/sanford_bishop/1_face_13.05georgia-cnd-jumbo.jpg
#   inflating: faces/sanford_bishop/1_face_18.607b283172993.image.jpg
#   inflating: faces/sanford_bishop/1_face_9.sanford_bishop.jpg
#   inflating: faces/sanford_bishop/0_face_9.sanford_bishop.jpg
#   inflating: faces/sanford_bishop/1_face_19.56795507_2384927674874541_8541956933970558976_o.jpg
#   inflating: faces/sanford_bishop/1_face_21.4fx7czx7h5k7ve6ltprlv3xrda.jpg
#   inflating: faces/sanford_bishop/0_face_12.sanford-bishop-fsg.jpg
#   inflating: faces/sanford_bishop/0_face_19.56795507_2384927674874541_8541956933970558976_o.jpg
#   inflating: faces/sanford_bishop/0_face_6.bishop_bc_110717_087.jpg
#   inflating: faces/sanford_bishop/0_face_26.afa42316e5cbe04d03cd6f19857f49d1.jpg
#   inflating: faces/sanford_bishop/0_face_15.5f7b1ca7a681e.image.jpg
#   inflating: faces/sanford_bishop/0_face_4.b000490.jpg
#   inflating: faces/sanford_bishop/1_face_5.img_0338.jpg
#   inflating: faces/sanford_bishop/0_face_16.house_dems089_051519.jpg
#   inflating: faces/sanford_bishop/4_face_19.56795507_2384927674874541_8541956933970558976_o.jpg
#   inflating: faces/sanford_bishop/3_face_19.56795507_2384927674874541_8541956933970558976_o.jpg
#   inflating: faces/sanford_bishop/2_face_11.20200731-sanfordbishop-gty-773.jpg
#    creating: faces/ann_kirkpatrick/
#   inflating: faces/ann_kirkpatrick/1_face_28.kirkpatrick-web-002.jpg
#   inflating: faces/ann_kirkpatrick/0_face_20.5bb400f6153f5.image.jpg
#   inflating: faces/ann_kirkpatrick/0_face_14.kirkpatrickann_010319gn2_lead.jpg
#   inflating: faces/ann_kirkpatrick/0_face_27.rep-ann-kirkpatrick-looks-to-defend-her-seat-against-brandon-martin-in-arizonas-2nd-congressional-district.jpg
#   inflating: faces/ann_kirkpatrick/0_face_8.5f2b0395c9b84.image.jpg
#   inflating: faces/ann_kirkpatrick/2_face_15.ann-kirkpatrick-official.jpg
#   inflating: faces/ann_kirkpatrick/0_face_1.ann_kirkpatrick%2c_official_portrait%2c_116th_congress.jpg
#   inflating: faces/ann_kirkpatrick/0_face_23.kirkpatrick003_050714.jpg
#   inflating: faces/ann_kirkpatrick/0_face_26.edlniz2u8aeceq1.jpg
#   inflating: faces/ann_kirkpatrick/0_face_2.lmn9i3d5.jpg
#   inflating: faces/ann_kirkpatrick/0_face_3.412286-200px.jpeg
#   inflating: faces/ann_kirkpatrick/0_face_15.ann-kirkpatrick-official.jpg
#   inflating: faces/ann_kirkpatrick/0_face_10.anna-1024x511.jpg
#   inflating: faces/ann_kirkpatrick/0_face_6.220px-ann_kirkpatrick.jpg
#   inflating: faces/ann_kirkpatrick/0_face_17.jdhwfqcnsnef3menlryklds254.jpg
#   inflating: faces/ann_kirkpatrick/0_face_13.5bbd8ab420f73.image.jpg
#   inflating: faces/ann_kirkpatrick/1_face_26.edlniz2u8aeceq1.jpg
#   inflating: faces/ann_kirkpatrick/1_face_15.ann-kirkpatrick-official.jpg
#   inflating: faces/ann_kirkpatrick/0_face_7..jpg
#   inflating: faces/ann_kirkpatrick/0_face_25.ap501893277262_wide-fe3eff4cf81f950c3f3779a1a3878a25971c56a1-1500x844.jpg
#   inflating: faces/ann_kirkpatrick/0_face_16.k000368.jpg
#   inflating: faces/ann_kirkpatrick/0_face_9.https%3a%2f%2fcdn.cnn.com%2fcnnnext%2fdam%2fassets%2f200115153158-02-ann-kirkpatrick-file.jpg
#   inflating: faces/ann_kirkpatrick/0_face_12.3000.jpeg
#   inflating: faces/ann_kirkpatrick/0_face_11.873fc35b-06dc-4449-8470-3904c0cdc4a4-5496.jpg
#   inflating: faces/ann_kirkpatrick/0_face_29.636679572734622384-pnibrd2-11-06-2016-republic-1-a010-2016-11-05-img--tb-b3396.jpg-201611-1-1-higa5mme-l914183576-img--tb-b3396.jpg-201611-1-1-higa5mme.jpg
#   inflating: faces/ann_kirkpatrick/1_face_25.ap501893277262_wide-fe3eff4cf81f950c3f3779a1a3878a25971c56a1-1500x844.jpg
#   inflating: faces/ann_kirkpatrick/1_face_8.5f2b0395c9b84.image.jpg
#   inflating: faces/ann_kirkpatrick/0_face_5.106338451-1579113060594gettyimages-1061205834.jpeg
#   inflating: faces/ann_kirkpatrick/0_face_30.senatekirkpatrick-800.jpg
#   inflating: faces/ann_kirkpatrick/0_face_24.kirkpatrick-dc.jpg
#   inflating: faces/ann_kirkpatrick/0_face_19.220px-ann_kirkpatrick_by_gage_skidmore.jpg
#   inflating: faces/ann_kirkpatrick/0_face_28.kirkpatrick-web-002.jpg
#   inflating: faces/ann_kirkpatrick/0_face_21.anne_kirkpatrick_1.jpg
#   inflating: faces/ann_kirkpatrick/0_face_4.636361654247001779-pnibrd2-12-26-2016-republic-1-a012--2016-12-25-img-ann-kirkpatrick-1-1-86grqbqb-l944136738-img-ann-kirkpatrick-1-1-86grqbqb.jpg
#   inflating: faces/ann_kirkpatrick/0_face_22.longtime_arizona_rep_kirkpatrick_t715.jpg
#    creating: faces/debbie_dingell/
#   inflating: faces/debbie_dingell/1_face_29.220px-congressman_john_dingell_2011_ypsilanti_independence_day_parade_%28cropped%29.jpg
#   inflating: faces/debbie_dingell/2_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/0_face_23.https%3a%2f%2fcdn.cnn.com%2fcnnnext%2fdam%2fassets%2f161025121804-debbie-dingell.jpg
#   inflating: faces/debbie_dingell/0_face_6.img_1246.jpg
#   inflating: faces/debbie_dingell/1_face_4.john%20and%20debbie%20dingell_bloomberg_i.jpg
#   inflating: faces/debbie_dingell/0_face_27.191216175045-debbie-dingell-trump-split.jpg
#   inflating: faces/debbie_dingell/2_face_9.ap080616022101-dbd16de2b6528dcbc2c70cb3b7f36e1d005bd8dd.jpg
#   inflating: faces/debbie_dingell/1_face_7..jpg
#   inflating: faces/debbie_dingell/1_face_9.ap080616022101-dbd16de2b6528dcbc2c70cb3b7f36e1d005bd8dd.jpg
#   inflating: faces/debbie_dingell/1_face_8..jpg
#   inflating: faces/debbie_dingell/1_face_27.191216175045-debbie-dingell-trump-split.jpg
#   inflating: faces/debbie_dingell/0_face_15.00dingell-01-mediumsquareat3x.jpg
#   inflating: faces/debbie_dingell/3_face_19.n_witt_debbiedingell_190330_1920x1080.jpg
#   inflating: faces/debbie_dingell/0_face_22..jpg
#   inflating: faces/debbie_dingell/1_face_26.debbie_dingell.jpg
#   inflating: faces/debbie_dingell/0_face_11.debbie-dingell-fred-upton-composite.jpg
#   inflating: faces/debbie_dingell/3_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/1_face_22..jpg
#   inflating: faces/debbie_dingell/0_face_3.412637-200px.jpeg
#   inflating: faces/debbie_dingell/0_face_19.n_witt_debbiedingell_190330_1920x1080.jpg
#   inflating: faces/debbie_dingell/2_face_24.debbie-dingell-john-dingell.jpg
#   inflating: faces/debbie_dingell/0_face_28.d_debbiedingell.jpg
#   inflating: faces/debbie_dingell/5_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/0_face_8..jpg
#   inflating: faces/debbie_dingell/0_face_13.image.jpg
#   inflating: faces/debbie_dingell/0_face_26.debbie_dingell.jpg
#   inflating: faces/debbie_dingell/1_face_13.image.jpg
#   inflating: faces/debbie_dingell/0_face_10.image_asset_89127.jpg
#   inflating: faces/debbie_dingell/7_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/0_face_20.dingelldebbie_092419gn_lead.jpg
#   inflating: faces/debbie_dingell/1_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/0_face_9.ap080616022101-dbd16de2b6528dcbc2c70cb3b7f36e1d005bd8dd.jpg
#   inflating: faces/debbie_dingell/2_face_29.220px-congressman_john_dingell_2011_ypsilanti_independence_day_parade_%28cropped%29.jpg
#   inflating: faces/debbie_dingell/3_face_22..jpg
#   inflating: faces/debbie_dingell/0_face_14.ky5mjef22nb73c3g5jub653kvy.jpeg
#   inflating: faces/debbie_dingell/0_face_21.5849d1b195593.image.jpg
#   inflating: faces/debbie_dingell/0_face_1.debbie_dingell_official_headshot.jpg
#   inflating: faces/debbie_dingell/0_face_12.4a278601-85d7-4e2c-a183-b9004070520b-dingell_011416_kg_16.jpg
#   inflating: faces/debbie_dingell/0_face_5..jpg
#   inflating: faces/debbie_dingell/0_face_16.braszg2zmjc5vkps5zjxtmjmsq.png.jpg
#   inflating: faces/debbie_dingell/0_face_7..jpg
#   inflating: faces/debbie_dingell/0_face_17.1393356004000-debbie-dingell.jpg
#   inflating: faces/debbie_dingell/1_face_19.n_witt_debbiedingell_190330_1920x1080.jpg
#   inflating: faces/debbie_dingell/1_face_25.debbie_ne6is9.jpg
#   inflating: faces/debbie_dingell/1_face_24.debbie-dingell-john-dingell.jpg
#   inflating: faces/debbie_dingell/1_face_11.debbie-dingell-fred-upton-composite.jpg
#   inflating: faces/debbie_dingell/1_face_10.image_asset_89127.jpg
#   inflating: faces/debbie_dingell/1_face_17.1393356004000-debbie-dingell.jpg
#   inflating: faces/debbie_dingell/0_face_18.5e1e0c2325998.image.jpg
#   inflating: faces/debbie_dingell/0_face_25.debbie_ne6is9.jpg
#   inflating: faces/debbie_dingell/4_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/2_face_22..jpg
#   inflating: faces/debbie_dingell/0_face_4.john%20and%20debbie%20dingell_bloomberg_i.jpg
#   inflating: faces/debbie_dingell/2_face_19.n_witt_debbiedingell_190330_1920x1080.jpg
#   inflating: faces/debbie_dingell/1_face_14.ky5mjef22nb73c3g5jub653kvy.jpeg
#   inflating: faces/debbie_dingell/9_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/8_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/0_face_2.gm-debbie-dingell.jpg
#   inflating: faces/debbie_dingell/6_face_30.lede.debbiedingell.jpg
#   inflating: faces/debbie_dingell/0_face_29.220px-congressman_john_dingell_2011_ypsilanti_independence_day_parade_%28cropped%29.jpg
#   inflating: faces/debbie_dingell/0_face_24.debbie-dingell-john-dingell.jpg
#   inflating: faces/debbie_dingell/0_face_30.lede.debbiedingell.jpg
#    creating: faces/conor_lamb/
#   inflating: faces/conor_lamb/0_face_15.9d5eed47a6d7739839f232d97f0a502240-13-conor-lamb-marines.rsquare.w1200.jpg
#   inflating: faces/conor_lamb/2_face_25.931366294.jpg.jpg
#   inflating: faces/conor_lamb/0_face_22.griswold-conor-lamb-special-election.jpg
#   inflating: faces/conor_lamb/0_face_27.180306-conorlamb-editorial.jpg
#   inflating: faces/conor_lamb/0_face_8.img_1728-1920x1280.jpg
#   inflating: faces/conor_lamb/1_face_29.gettyimages-931659476_custom-2fdedd4c72ad1a5acef1e51e6c53db3b2dbd25ad.jpg
#   inflating: faces/conor_lamb/0_face_29.gettyimages-931659476_custom-2fdedd4c72ad1a5acef1e51e6c53db3b2dbd25ad.jpg
#   inflating: faces/conor_lamb/1_face_17.conorlamb-sean-parnell.jpg
#   inflating: faces/conor_lamb/1_face_18.3400177_web1_ap21007252977424.jpg
#   inflating: faces/conor_lamb/2_face_14.conor-lamb-joe-biden-ap-jef-180306_16x9_1600.jpg
#   inflating: faces/conor_lamb/0_face_5.200527-conor-lamb-al-0923_e0820d36168c3ea513e0b6304a51e8ee.jpg
#   inflating: faces/conor_lamb/0_face_17.conorlamb-sean-parnell.jpg
#   inflating: faces/conor_lamb/0_face_25.931366294.jpg.jpg
#   inflating: faces/conor_lamb/0_face_26.6580003940-1080pnbcstations.jpg
#   inflating: faces/conor_lamb/0_face_13.2018-04-12_knb_1085.jpg
#   inflating: faces/conor_lamb/0_face_20.20180515dslamblocal02-1-1569424840.jpg
#   inflating: faces/conor_lamb/0_face_18.3400177_web1_ap21007252977424.jpg
#   inflating: faces/conor_lamb/0_face_12.4c9f184e-11dc-416b-b52b-e106a2860ec4-ap_pennsylvania_lamb_99133123.jpg
#   inflating: faces/conor_lamb/0_face_2.2018-04-12_knb_1061.jpg
#   inflating: faces/conor_lamb/1_face_13.2018-04-12_knb_1085.jpg
#   inflating: faces/conor_lamb/0_face_14.conor-lamb-joe-biden-ap-jef-180306_16x9_1600.jpg
#   inflating: faces/conor_lamb/1_face_20.20180515dslamblocal02-1-1569424840.jpg
#   inflating: faces/conor_lamb/2_face_29.gettyimages-931659476_custom-2fdedd4c72ad1a5acef1e51e6c53db3b2dbd25ad.jpg
#   inflating: faces/conor_lamb/2_face_18.3400177_web1_ap21007252977424.jpg
#   inflating: faces/conor_lamb/0_face_19.conor-lamb-share-1200x630.jpg
#   inflating: faces/conor_lamb/0_face_3.20275626-8888-4d0a-9788-06e2efebc04a.sized-1000x1000.jpg
#   inflating: faces/conor_lamb/2_face_26.6580003940-1080pnbcstations.jpg
#   inflating: faces/conor_lamb/1_face_14.conor-lamb-joe-biden-ap-jef-180306_16x9_1600.jpg
#   inflating: faces/conor_lamb/0_face_1.conor_lamb%2c_official_portrait%2c_115th_congress.jpg
#   inflating: faces/conor_lamb/0_face_21.conor_lamb_joe_biden.jpg
#   inflating: faces/conor_lamb/1_face_21.conor_lamb_joe_biden.jpg
#   inflating: faces/conor_lamb/1_face_16.62aab1f74ae790ad5c246b0240713ed7.jpg
#   inflating: faces/conor_lamb/0_face_28.16lamb-biden1-mediumsquareat3x.jpg
#   inflating: faces/conor_lamb/0_face_7.lamb0901-1609087388.jpg
#   inflating: faces/conor_lamb/1_face_26.6580003940-1080pnbcstations.jpg
#   inflating: faces/conor_lamb/0_face_9.40_government_lamb.jpg
#   inflating: faces/conor_lamb/1_face_25.931366294.jpg.jpg
#   inflating: faces/conor_lamb/0_face_16.62aab1f74ae790ad5c246b0240713ed7.jpg
#   inflating: faces/conor_lamb/0_face_6.08lamb-mobilemasterat3x.jpg
#   inflating: faces/conor_lamb/1_face_2.2018-04-12_knb_1061.jpg
#   inflating: faces/conor_lamb/0_face_24.39957_lamb-conor.jpg
#   inflating: faces/conor_lamb/3_face_25.931366294.jpg.jpg
#   inflating: faces/conor_lamb/0_face_11.conor_lamb.jpg
#   inflating: faces/conor_lamb/1_face_30.904588742.jpg.0.jpg
#   inflating: faces/conor_lamb/0_face_30.904588742.jpg.0.jpg
#   inflating: faces/conor_lamb/0_face_23.40636199252_55e8222359_k-1024x576.jpg
#   inflating: faces/conor_lamb/0_face_4.lambconor_111518gn_lead.jpg
#   inflating: faces/conor_lamb/0_face_10.election-2020-pennsylvania-house-1604792838.jpg
#    creating: faces/david_mckinley/
#   inflating: faces/david_mckinley/1_face_19.f5vrku3l5jgdpmsmskfouxbhbi.jpg
#   inflating: faces/david_mckinley/1_face_26.mckinley4-901x683.jpg
#   inflating: faces/david_mckinley/0_face_20.dyrq37hwaaaw99z.jpg
#   inflating: faces/david_mckinley/0_face_17.4du4o24xbbmejjwu3bxlzapmwq.jpg
#   inflating: faces/david_mckinley/0_face_22.110418_david_mckinley_ap110316035770.jpg
#   inflating: faces/david_mckinley/0_face_12..jpg
#   inflating: faces/david_mckinley/0_face_3.mckinleydavid_010615gn_lead.jpg
# ...
#   inflating: faces/mark_amodei/0_face_5.amodei.jpeg
#   inflating: faces/mark_amodei/0_face_10.12781971_web1_amodei-breakfast-feb23-19-bt04.jpg
#   inflating: faces/mark_amodei/0_face_6.2020-03-10-ncu-blog-site-visit.jpg
#   inflating: faces/mark_amodei/0_face_23.e42046a8e686fd020d7aee027ee7ac9a96-01-mark-amodei.rsquare.w700.jpg
#   inflating: faces/mark_amodei/5_face_6.2020-03-10-ncu-blog-site-visit.jpg
#   inflating: faces/mark_amodei/0_face_19.bztmsnvlhzli3p2aenxmfzle3y.jpg
#   inflating: faces/mark_amodei/0_face_18.14980898_web1_governoer-composite.jpg
#   inflating: faces/mark_amodei/2_face_11.d80b1a6f-6590-43b7-ac5a-0d4e0fbccfe9-gty_969195940.jpg
#   inflating: faces/mark_amodei/1_face_26.amodei-co-chair-featured-og.jpg
#   inflating: faces/mark_amodei/0_face_25.merlin_139196256_238f02a7-d7cd-4721-b5c6-5a4f9c5cfc5b-videosixteenbyninejumbo1600.jpg
#   inflating: faces/mark_amodei/3_face_6.2020-03-10-ncu-blog-site-visit.jpg
#   inflating: faces/mark_amodei/3_face_30.mark_amodei_marcia_neel_steve_gibson.jpg
#   inflating: faces/mark_amodei/2_face_26.amodei-co-chair-featured-og.jpg
#   inflating: faces/mark_amodei/0_face_26.amodei-co-chair-featured-og.jpg
#   inflating: faces/mark_amodei/0_face_3.2cc511d1-e9fa-460b-ad40-16cea1c42633-large3x4_mark_amodei.jpg
#   inflating: faces/mark_amodei/2_face_14.b2ap3_amp_mark-amodei-speaking.jpg
#   inflating: faces/mark_amodei/0_face_11.d80b1a6f-6590-43b7-ac5a-0d4e0fbccfe9-gty_969195940.jpg
#   inflating: faces/mark_amodei/0_face_13.636258069928918806-xxx-ja-gan-amodei-131446-53.jpg
#   inflating: faces/mark_amodei/0_face_17.amodei-eggs-and-issues.jpg
#   inflating: faces/mark_amodei/1_face_30.mark_amodei_marcia_neel_steve_gibson.jpg
#    creating: faces/yvette_clarke/
#   inflating: faces/yvette_clarke/0_face_19.congresswoman-yvette-d.-clarke-1.jpg
#   inflating: faces/yvette_clarke/1_face_23.adem-yvette-clarke-congress.jpg
#   inflating: faces/yvette_clarke/0_face_28.brooklyn-rep-yvette-clarke-clarkhousegov-1.jpg
#   inflating: faces/yvette_clarke/0_face_5.yvette-clarke.jpg
#   inflating: faces/yvette_clarke/0_face_7.412221-200px.jpeg
#   inflating: faces/yvette_clarke/4_face_9.v5sfxq7eyjerdbf36uzmoyb3em.jpg
#   inflating: faces/yvette_clarke/0_face_22.collage-14.jpg
#   inflating: faces/yvette_clarke/3_face_14.repyetteclarke-600-b.jpg
#   inflating: faces/yvette_clarke/1_face_25.rep-clarke-with-potus-1.jpg
#   inflating: faces/yvette_clarke/0_face_16.shutterstock_5592165h-1530039186-9594.jpg
#   inflating: faces/yvette_clarke/0_face_4.clarke-yvette-courtesy-clarke-1024x766.jpg
#   inflating: faces/yvette_clarke/1_face_14.repyetteclarke-600-b.jpg
#   inflating: faces/yvette_clarke/0_face_15.usaclwqi_400x400.jpg
#   inflating: faces/yvette_clarke/0_face_17.c001067.jpg
#   inflating: faces/yvette_clarke/0_face_13.clarkeyvette_111518gn_lead.jpg
#   inflating: faces/yvette_clarke/0_face_9.v5sfxq7eyjerdbf36uzmoyb3em.jpg
#   inflating: faces/yvette_clarke/0_face_30.a_ov_yvette_townhall_170222.jpg
#   inflating: faces/yvette_clarke/1_face_19.congresswoman-yvette-d.-clarke-1.jpg
#   inflating: faces/yvette_clarke/4_face_24.9a4d4492a9bbe1164353f36ee15385305420_053119_yvette_clarke.jpg
#   inflating: faces/yvette_clarke/3_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/1_face_16.shutterstock_5592165h-1530039186-9594.jpg
#   inflating: faces/yvette_clarke/5_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/0_face_24.9a4d4492a9bbe1164353f36ee15385305420_053119_yvette_clarke.jpg
#   inflating: faces/yvette_clarke/0_face_1.yvette_clarke_official_photo.jpg
#   inflating: faces/yvette_clarke/0_face_11.clarke.jpg
#   inflating: faces/yvette_clarke/0_face_20.yvette-clarke_1920x1080-1-1920x1080.jpg
#   inflating: faces/yvette_clarke/1_face_13.clarkeyvette_111518gn_lead.jpg
#   inflating: faces/yvette_clarke/3_face_9.v5sfxq7eyjerdbf36uzmoyb3em.jpg
#   inflating: faces/yvette_clarke/7_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/1_face_9.v5sfxq7eyjerdbf36uzmoyb3em.jpg
#   inflating: faces/yvette_clarke/1_face_6.eramrittrzgwvokaphjb53ed4q.jpg
#   inflating: faces/yvette_clarke/0_face_3.022217_ap_yvetteclarke3840x2160jpg.jpg
#   inflating: faces/yvette_clarke/0_face_6.eramrittrzgwvokaphjb53ed4q.jpg
#   inflating: faces/yvette_clarke/0_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/0_face_2.c001067.jpg
#   inflating: faces/yvette_clarke/2_face_9.v5sfxq7eyjerdbf36uzmoyb3em.jpg
#   inflating: faces/yvette_clarke/0_face_25.rep-clarke-with-potus-1.jpg
#   inflating: faces/yvette_clarke/0_face_12.yvette%20clarke%20.jpg
#   inflating: faces/yvette_clarke/0_face_27.37bb9352-4ea7-441f-a382-2fbf5ee1f1ff.jpg
#   inflating: faces/yvette_clarke/6_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/0_face_23.adem-yvette-clarke-congress.jpg
#   inflating: faces/yvette_clarke/1_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/0_face_14.repyetteclarke-600-b.jpg
#   inflating: faces/yvette_clarke/0_face_26.clarkemobile.jpg
#   inflating: faces/yvette_clarke/1_face_24.9a4d4492a9bbe1164353f36ee15385305420_053119_yvette_clarke.jpg
#   inflating: faces/yvette_clarke/1_face_30.a_ov_yvette_townhall_170222.jpg
#   inflating: faces/yvette_clarke/0_face_18.c85907c07b035261cc2bc5b9b9bdd048cf62_yvette_clarke.w460.a460x575.2x.jpg
#   inflating: faces/yvette_clarke/2_face_23.adem-yvette-clarke-congress.jpg
#   inflating: faces/yvette_clarke/2_face_14.repyetteclarke-600-b.jpg
#   inflating: faces/yvette_clarke/4_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/3_face_24.9a4d4492a9bbe1164353f36ee15385305420_053119_yvette_clarke.jpg
#   inflating: faces/yvette_clarke/2_face_21.5eeba0a65af6cc6c3e0f6426.jpg
#   inflating: faces/yvette_clarke/2_face_24.9a4d4492a9bbe1164353f36ee15385305420_053119_yvette_clarke.jpg
#   inflating: faces/yvette_clarke/0_face_29.clarke_y.jpg
#   inflating: faces/yvette_clarke/0_face_8.clarke.jpg
#   inflating: faces/yvette_clarke/0_face_10.yvette-d.-clarke.jpg
#    creating: faces/henry_cuellar/
#   inflating: faces/henry_cuellar/0_face_19.henrycuellar.jpg
#   inflating: faces/henry_cuellar/0_face_13.cuellar_bc_200_072517.jpg
#   inflating: faces/henry_cuellar/2_face_16.cuellar-questioned-by-reporters-img.jpg
#   inflating: faces/henry_cuellar/0_face_8.26n37rjeojcnfn57kmy3v7trni.jpg
#   inflating: faces/henry_cuellar/0_face_21.henry-cuellar-1-800x450-c-default.jpg
#   inflating: faces/henry_cuellar/0_face_27.e51b9088-e1d5-42a7-8176-2e3c2a3bde9e_1920x1080.jpg
#   inflating: faces/henry_cuellar/3_face_18.4e0bfed8-fbbf-4ecd-9ea5-20a39cb05445.jpg
#   inflating: faces/henry_cuellar/0_face_2.henry_cuellar.jpg
#   inflating: faces/henry_cuellar/0_face_12..jpg
#   inflating: faces/henry_cuellar/2_face_14.cuellarhenry_010319gn2_lead.jpg
#   inflating: faces/henry_cuellar/0_face_7.gettyimages_1001875962.0.jpg
#   inflating: faces/henry_cuellar/3_face_4.cuellarfamily_0.jpg
#   inflating: faces/henry_cuellar/0_face_10.rawimage.jpg
#   inflating: faces/henry_cuellar/4_face_18.4e0bfed8-fbbf-4ecd-9ea5-20a39cb05445.jpg
#   inflating: faces/henry_cuellar/0_face_24.henry-cuellar-d-texas.jpg
#   inflating: faces/henry_cuellar/0_face_17.200131-2x1-jessica-cisneros-henry-cuellar-ew-720p_c571b5b70186cdedbefdf2c1ad55f6e8.nbcnews-fp-1200-630.jpg
#   inflating: faces/henry_cuellar/1_face_14.cuellarhenry_010319gn2_lead.jpg
#   inflating: faces/henry_cuellar/0_face_15.uscyiany3rigjmu7bzkxoqwbgi.jpg
#   inflating: faces/henry_cuellar/0_face_6.ap_17256749412377-1000x666.jpg
#   inflating: faces/henry_cuellar/1_face_23._01f2562.jpg
#   inflating: faces/henry_cuellar/0_face_28.qsohbddb_400x400.jpg
#   inflating: faces/henry_cuellar/0_face_4.cuellarfamily_0.jpg
#   inflating: faces/henry_cuellar/1_face_16.cuellar-questioned-by-reporters-img.jpg
#   inflating: faces/henry_cuellar/0_face_18.4e0bfed8-fbbf-4ecd-9ea5-20a39cb05445.jpg
#   inflating: faces/henry_cuellar/1_face_10.rawimage.jpg
#   inflating: faces/henry_cuellar/0_face_1.henry_cuellar%2c_official_portrait%2c_115th_congress.jpg
#   inflating: faces/henry_cuellar/0_face_16.cuellar-questioned-by-reporters-img.jpg
#   inflating: faces/henry_cuellar/0_face_22.henry-cuellar.jpg
#   inflating: faces/henry_cuellar/2_face_11.pelosi%20cuellar%20rj%20tt%2001.jpg
#   inflating: faces/henry_cuellar/1_face_4.cuellarfamily_0.jpg
#   inflating: faces/henry_cuellar/1_face_12..jpg
#   inflating: faces/henry_cuellar/0_face_14.cuellarhenry_010319gn2_lead.jpg
#   inflating: faces/henry_cuellar/0_face_25.merlin_160228833_c6434947-196e-467a-89d1-8fc54e690864-jumbo.jpg
#   inflating: faces/henry_cuellar/1_face_30.henry-cuellar-web.jpg
#   inflating: faces/henry_cuellar/2_face_18.4e0bfed8-fbbf-4ecd-9ea5-20a39cb05445.jpg
#   inflating: faces/henry_cuellar/1_face_11.pelosi%20cuellar%20rj%20tt%2001.jpg
#   inflating: faces/henry_cuellar/0_face_5._8cp7ssc_400x400.jpg
#   inflating: faces/henry_cuellar/1_face_8.26n37rjeojcnfn57kmy3v7trni.jpg
#   inflating: faces/henry_cuellar/1_face_17.200131-2x1-jessica-cisneros-henry-cuellar-ew-720p_c571b5b70186cdedbefdf2c1ad55f6e8.nbcnews-fp-1200-630.jpg
#   inflating: faces/henry_cuellar/0_face_29.13-henry-cuellar.jpg
#   inflating: faces/henry_cuellar/0_face_30.henry-cuellar-web.jpg
#   inflating: faces/henry_cuellar/0_face_9.cuellar_bc_100417_065-1.jpg
#   inflating: faces/henry_cuellar/0_face_3.henry_cuellar.jpg
#   inflating: faces/henry_cuellar/0_face_11.pelosi%20cuellar%20rj%20tt%2001.jpg
#   inflating: faces/henry_cuellar/0_face_26.iudqxynn5dopajv6r4vlj422pe.jpg
#   inflating: faces/henry_cuellar/0_face_23._01f2562.jpg
#   inflating: faces/henry_cuellar/1_face_18.4e0bfed8-fbbf-4ecd-9ea5-20a39cb05445.jpg
#   inflating: faces/henry_cuellar/2_face_4.cuellarfamily_0.jpg
#   inflating: faces/henry_cuellar/1_face_9.cuellar_bc_100417_065-1.jpg
#   inflating: faces/henry_cuellar/0_face_20.lejmtau4jrbeqqpkjcfwyyimu4.jpg
#    creating: faces/salud_carbajal/
#   inflating: faces/salud_carbajal/0_face_26.572d44f1a70d4.image.jpg
#   inflating: faces/salud_carbajal/1_face_23.salud-carbajal-edhat_0.jpg
#   inflating: faces/salud_carbajal/5_face_21.5b97280cb28f8.image.jpg
#   inflating: faces/salud_carbajal/11_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/0_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/7_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/4_face_22.95b96921-085c-48b2-9b27-343abc83bf12.jpg
#   inflating: faces/salud_carbajal/0_face_13.b7ea94ad-3f45-48fb-9c9b-b8246530c706.jpg
#   inflating: faces/salud_carbajal/0_face_2.00f5de20-9c48-4158-8194-4c73bbc7e396.jpg
#   inflating: faces/salud_carbajal/2_face_18.527566f6-407b-4025-8a00-4d4de9a6655e.jpg
#   inflating: faces/salud_carbajal/3_face_21.5b97280cb28f8.image.jpg
#   inflating: faces/salud_carbajal/0_face_23.salud-carbajal-edhat_0.jpg
#   inflating: faces/salud_carbajal/3_face_24.salud-family_5731-1024x731.jpg
#   inflating: faces/salud_carbajal/0_face_9.5fff8b26cebc1.image.jpg
#   inflating: faces/salud_carbajal/2_face_24.salud-family_5731-1024x731.jpg
#   inflating: faces/salud_carbajal/1_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/1_face_27.042619-salud-carbajal-1-jm-1000x667_2400_1601_80_s_c1.jpg
#   inflating: faces/salud_carbajal/4_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/4_face_24.salud-family_5731-1024x731.jpg
#   inflating: faces/salud_carbajal/0_face_30.201006183725-salud-carbajal-file-restricted-super-tease.jpg
#   inflating: faces/salud_carbajal/0_face_20.carbajalsalud_111219gn_lead.jpg
#   inflating: faces/salud_carbajal/0_face_4.412686-200px.jpeg
#   inflating: faces/salud_carbajal/0_face_17.maxresdefault.jpg
#   inflating: faces/salud_carbajal/0_face_28.carbajal-caldwell-debate.jpg
#   inflating: faces/salud_carbajal/2_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/6_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/8_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/5_face_22.95b96921-085c-48b2-9b27-343abc83bf12.jpg
#   inflating: faces/salud_carbajal/2_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/3_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/5_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/0_face_1.1200px-salud_carbajal_official_photo.jpg
#   inflating: faces/salud_carbajal/0_face_18.527566f6-407b-4025-8a00-4d4de9a6655e.jpg
#   inflating: faces/salud_carbajal/0_face_22.95b96921-085c-48b2-9b27-343abc83bf12.jpg
#   inflating: faces/salud_carbajal/0_face_6.102718-carbajal-1000.jpg
#   inflating: faces/salud_carbajal/4_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/0_face_27.042619-salud-carbajal-1-jm-1000x667_2400_1601_80_s_c1.jpg
#   inflating: faces/salud_carbajal/0_face_19.01162015-salud-carbajal-02.jpg
#   inflating: faces/salud_carbajal/7_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/6_face_22.95b96921-085c-48b2-9b27-343abc83bf12.jpg
#   inflating: faces/salud_carbajal/2_face_21.5b97280cb28f8.image.jpg
#   inflating: faces/salud_carbajal/1_face_29.60b5af69-227d-406a-96c4-78db93c762a3.jpg
#   inflating: faces/salud_carbajal/8_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/0_face_25.3000.jpeg
#   inflating: faces/salud_carbajal/1_face_28.carbajal-caldwell-debate.jpg
#   inflating: faces/salud_carbajal/1_face_21.5b97280cb28f8.image.jpg
#   inflating: faces/salud_carbajal/2_face_23.salud-carbajal-edhat_0.jpg
#   inflating: faces/salud_carbajal/0_face_29.60b5af69-227d-406a-96c4-78db93c762a3.jpg
#   inflating: faces/salud_carbajal/0_face_16.5bc14b52aa319.image.jpg
#   inflating: faces/salud_carbajal/1_face_10.2020-12-07-1.jpg
#   inflating: faces/salud_carbajal/0_face_3.salud_carbajal_115th_congress_photo.jpg
#   inflating: faces/salud_carbajal/0_face_21.5b97280cb28f8.image.jpg
#   inflating: faces/salud_carbajal/6_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/9_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/0_face_11.carbajalsalud_120116gn_lead.jpg
#   inflating: faces/salud_carbajal/2_face_22.95b96921-085c-48b2-9b27-343abc83bf12.jpg
#   inflating: faces/salud_carbajal/0_face_12.carbajal_2012.jpg
#   inflating: faces/salud_carbajal/1_face_22.95b96921-085c-48b2-9b27-343abc83bf12.jpg
#   inflating: faces/salud_carbajal/1_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/3_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/5_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/0_face_15.salud-carbajal-01152021.jpg
#   inflating: faces/salud_carbajal/0_face_24.salud-family_5731-1024x731.jpg
#   inflating: faces/salud_carbajal/0_face_10.2020-12-07-1.jpg
#   inflating: faces/salud_carbajal/1_face_20.carbajalsalud_111219gn_lead.jpg
#   inflating: faces/salud_carbajal/1_face_11.carbajalsalud_120116gn_lead.jpg
#   inflating: faces/salud_carbajal/1_face_18.527566f6-407b-4025-8a00-4d4de9a6655e.jpg
#   inflating: faces/salud_carbajal/0_face_8.5c301d79787fc.image.jpg
#   inflating: faces/salud_carbajal/10_face_5.010317-carbajal-sworn-in-1080_2400_1800_80_s_c1.jpg
#   inflating: faces/salud_carbajal/3_face_22.95b96921-085c-48b2-9b27-343abc83bf12.jpg
#   inflating: faces/salud_carbajal/1_face_24.salud-family_5731-1024x731.jpg
#   inflating: faces/salud_carbajal/4_face_21.5b97280cb28f8.image.jpg
#   inflating: faces/salud_carbajal/0_face_14.salud-carbajal-860x484.jpg
#   inflating: faces/salud_carbajal/0_face_7.salud-carbajal-240x300.jpg

# %% [markdown]
# After you run the code below, click the little folder icon on the left-hand side of the screen. You can browse around and see what files came out of it! You probably need to click the little folder refresh icon, too.

# %% [markdown]
# ## Looking at the images
#
# If you want to look at the images, you can use this code. It picks 16 random ones and displays them in a grid. **If you're feeling lazy, just continue onward without doing it!!!**
#
# ```python
# import glob
# import random
# import matplotlib.pyplot as plt
#
# # Get a list of all files
# filenames = glob.glob("faces/**/*")
#
# # Let's look at them!!!
# plt.figure(figsize=(10, 10))
# for i, filename in enumerate(random.sample(filenames, 16)):
#   ax = plt.subplot(4, 4, i + 1)
#   img = plt.imread(filename)
#   plt.imshow(img)
#   plt.title(filename.split("/")[1])
#   plt.axis("off")
# ```

# %%
import glob
import random
import matplotlib.pyplot as plt
 
# Get a list of all files
filenames = glob.glob("faces/**/*")
 
# Let's look at them!!!
plt.figure(figsize=(10, 10))
for i, filename in enumerate(random.sample(filenames, 16)):
  ax = plt.subplot(4, 4, i + 1)
  img = plt.imread(filename)
  plt.imshow(img)
  plt.title(filename.split("/")[1])
  plt.axis("off")

# %% [markdown]
# # Now, machine learning!
#
# ## Tensorflow setup
#
# Let's start by importing Tensorflow and whatever else we might need.

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt

# %% [markdown]
# So far our images have always been RGB and sized 224x224, so that's what we're going to stick with again. We use 224x224 because the networks we've seen are trained with that size, so it's the only size image they can understand!
#
# > Note: It isn't *all* networks that need 224x224, just the ones we've looked at so far.
#
# **Update `IMAGE_SIZE` to reflect the size image our neural network will want.**

# %%
# Magic numbers for success
IMAGE_SIZE = (224, 224)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

# %% [markdown]
# ## Loading our data
#
# When we did classification in class, we used `tf.keras.preprocessing.image_dataset_from_directory` to, well, load an image dataset from a directory! Since nothing can ever be simple, there are a hundred other ways to do it, too.
#
# This time we're going to use `flow_from_directory` instead. It works almost exactly the same, but it's more efficient if you need to do things like change `0-255` to `0-1` or perform image augmentations to get rotated/zoomed/flipped versions of your photos. Which I guess we do?
#
# **Change `data_dir` to point at to the folder that contains our images.**

# %%
# Magic code for success

#!ls /content/gdrive/MyDrive/

data_dir = '/content/gdrive/MyDrive/faces'
datagen_kwargs = dict(rescale=1./255, validation_split=.10)
dataflow_kwargs = dict(target_size=IMAGE_SIZE, interpolation="bilinear", class_mode='sparse')

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    **datagen_kwargs)
valid_generator = valid_datagen.flow_from_directory(
    data_dir, subset="validation", shuffle=False, **dataflow_kwargs)

train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=5,
    horizontal_flip=True,
    width_shift_range=0.2, height_shift_range=0.2,
    shear_range=0.2, zoom_range=0.2,
    **datagen_kwargs)

train_generator = train_datagen.flow_from_directory(
    data_dir, subset="training", shuffle=True, **dataflow_kwargs)
# Out:
# Found 24 images belonging to 536 classes.
# Found 248 images belonging to 536 classes.

# %% [markdown]
# The output should look like this:
#
# ```
# Found 2777 images belonging to 536 classes.
# Found 27391 images belonging to 536 classes.
# ```

# %% [markdown]
# ## Building our model
#
# In class, we tried two approaches to building an image classifier:
#
# 1. Use ImageNet's pre-trained 1,000 categories to figure out what was in images
# 2. Use our own custom network and some custom images we downloaded to train a brand-new model
#
# It turns out there's also a third approach, where you **start with a model that knows about some things, but then you teach it to recognize new things.** This is called **transfer learning.**
#
# Transfer learning is useful because the model probably already knows about color and lines and circles and eyeballs and hair, which is how it knows a dog is different from an airplane. We just say hey, use what you know about color and lines and circles and eyeballs and hair to tell different people apart instead of dogs and planes!
#
# ## Selecting a pre-trained model and architecture
#
# Below you have **three options** of models that you can start from.
#
# 1. **MobileNet:** A network that is optimized for size, and so it's easier to transfer to mobile devices
# 2. **ResNet 50:** A 50-layer residual network
# 3. **ResNet 101:** A 101-layer residual network (like ResNet 50, just bigger)
#
# The difference is the "magic insides" that go between the inputs and the outputs - we don't understand what the insides are, but we still have to make a choice. They've all been trained on ImageNet, so they should in theory all know basically the same stuff.
#
# **Pick a pre-trained model by uncommenting one of the lines below, then running the cell.** If you want, you can read about them by visiting the URL in your browser.

# %%
base_model_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"
# base_model_url = "https://tfhub.dev/tensorflow/resnet_50/feature_vector/1"
# base_model_url = "https://tfhub.dev/google/imagenet/resnet_v2_101/feature_vector/5"

# download the model from 
pretrained_model = hub.KerasLayer(base_model_url, trainable=False)

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
    pretrained_model,
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(train_generator.num_classes,
                          activation='softmax')
])
model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 536)               686616
# =================================================================
# Total params: 2,944,600
# Trainable params: 686,616
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# Remember: we're using a **softmax** layer at the end because we want probabilities! Softmax = probabilities!!!

# %% [markdown]
# ## Settings for training our model
#
# Before we train, we need to `.compile` our model. Which I guess is just some sort of setup? It doesn't matter what it is, we just have to do it!!
#
# **Optimizer:** Our optimizer is `adam`, because that's... what people always use. Not *always* always, but since we don't even know what an optimizer is who cares.
#
# **Loss:** We're trying to predict categories, so our loss is either going to be `SparseCategoricalCrossentropy()` or `CategoricalCrossentropy()`. We aren't the first people to be confused about this, so maybe [read this question and answer](https://datascience.stackexchange.com/questions/41921/sparse-categorical-crossentropy-vs-categorical-crossentropy-keras-accuracy) and try the one you think makes the most sense.
#
# **Metrics:** We want to make our classifier accurate, so our metric is... `accuracy`.
#
# **Set the appropriate loss function below.**

# %%
model.compile(
  optimizer='adam', 
  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  metrics=['accuracy'])

# %% [markdown]
# ## Training the model
#
# Here we go!!! Let's do it!!!
#
# **Pick the number of epochs you want to train for.** It's going to be a tradeoff between accuracy and how long it takes! Right now I have it set for a single epoch, which is definitely not enough.
#
# > If it's taking a really long time to train an epoch (more than 5-10 minutes), we want to make sure you're using the GPU! Click **Runtime** at the top of the screen, then **Change runtime type** and change **Hardware accelerator** to **GPU**. This will make everything faster.
#
# Even though Google Colab will let you run this for up to 12 hours, for this exercise I recommend not going any longer than an hour.

# %%
num_epochs = 20

steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size
model.fit(
    train_generator,
    epochs=num_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=validation_steps)
# Out:
# Epoch 1/20
# 7/7 [==============================] - 3s 403ms/step - loss: 0.7901 - accuracy: 0.7315
# Epoch 2/20
# 7/7 [==============================] - 3s 378ms/step - loss: 0.8223 - accuracy: 0.7188
# Epoch 3/20
# 7/7 [==============================] - 3s 359ms/step - loss: 0.7967 - accuracy: 0.7407
# Epoch 4/20
# 7/7 [==============================] - 3s 368ms/step - loss: 0.7142 - accuracy: 0.7685
# Epoch 5/20
# 7/7 [==============================] - 3s 359ms/step - loss: 0.7541 - accuracy: 0.7454
# Epoch 6/20
# 7/7 [==============================] - 3s 360ms/step - loss: 0.7261 - accuracy: 0.7454
# Epoch 7/20
# 7/7 [==============================] - 3s 378ms/step - loss: 0.6720 - accuracy: 0.7731
# Epoch 8/20
# 7/7 [==============================] - 3s 366ms/step - loss: 0.6666 - accuracy: 0.7917
# Epoch 9/20
# 7/7 [==============================] - 3s 357ms/step - loss: 0.6813 - accuracy: 0.7824
# Epoch 10/20
# 7/7 [==============================] - 3s 356ms/step - loss: 0.6730 - accuracy: 0.7963
# Epoch 11/20
# 7/7 [==============================] - 3s 365ms/step - loss: 0.6835 - accuracy: 0.7778
# Epoch 12/20
# 7/7 [==============================] - 3s 364ms/step - loss: 0.6957 - accuracy: 0.7361
# Epoch 13/20
# 7/7 [==============================] - 3s 364ms/step - loss: 0.6191 - accuracy: 0.8056
# Epoch 14/20
# 7/7 [==============================] - 3s 364ms/step - loss: 0.6271 - accuracy: 0.7685
# Epoch 15/20
# 7/7 [==============================] - 3s 366ms/step - loss: 0.6011 - accuracy: 0.7685
# Epoch 16/20
# 7/7 [==============================] - 3s 360ms/step - loss: 0.5857 - accuracy: 0.8241
# Epoch 17/20
# 7/7 [==============================] - 3s 355ms/step - loss: 0.5326 - accuracy: 0.8380
# Epoch 18/20
# 7/7 [==============================] - 3s 373ms/step - loss: 0.5445 - accuracy: 0.8393
# Epoch 19/20
# 7/7 [==============================] - 3s 358ms/step - loss: 0.5270 - accuracy: 0.8519
# Epoch 20/20
# 7/7 [==============================] - 3s 366ms/step - loss: 0.5187 - accuracy: 0.8704

# %% [markdown]
# ## Your results
#
# How did it do?
#
# `accuracy` is a measure of how good your model is at things it's already seen (e.g. the "train" part of train/test split) and `val_accuracy` is a measure of how good it is at things it *hasn't* seen (e.g. the "test" part of train/test split).
#
# **Paste the last couple line of output into the cell below.** It should look something like this:
#
# ```python
# # Epoch 2/2
# # 855/855 [==============================] - 299s 349ms/step - loss: 5.5293 - accuracy: 0.0758 - val_loss: 5.1483 - val_accuracy: 0.1101
# ```
#
# After pasting, comment them out so it doesn't try to run them!

# %%
# Epoch 18/20
# 7/7 [==============================] - 3s 373ms/step - loss: 0.5445 - accuracy: 0.8393
# Epoch 19/20
# 7/7 [==============================] - 3s 358ms/step - loss: 0.5270 - accuracy: 0.8519
# Epoch 20/20
# 7/7 [==============================] - 3s 366ms/step - loss: 0.5187 - accuracy: 0.8704
# <tensorflow.python.keras.callbacks.History at 0x7f5ceeebed90>

# %% [markdown]
# ## Save your model to Google Drive
#
# Instead of downloading our model, we'll just save it to our Google Drive. Since we don't have a GPU at home (right?? we're on a laptop??), it would probably run too slowly on our machine anyway.

# %%
# Make a new folder called "models" on our drive
# !mkdir -p /content/gdrive/MyDrive/models/face_recognition_v1

# Save the model to that folder
model.save('/content/gdrive/MyDrive/models/face_recognition_v1')
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v1/assets
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v1/assets

# %% [markdown]
# We also need to save the names of everyone, because the model only knows numbers! Person 0, Person 1, Person 2, etc.

# %%
class_names = list(train_generator.class_indices.keys())
class_names[:5]
# Out:
# ['a._ferguson',
#  'a._mceachin',
#  'abigail_spanberger',
#  'adam_kinzinger',
#  'adam_schiff']

# %%
import json

with open('/content/gdrive/MyDrive/models/congress_labels.json', 'w') as fp:
  json.dump(class_names, fp)

# %% [markdown]
# # Trying another model
#
# We're going to try another model instead of whatever you picked above. **And this time I'm telling you which one to use.** Our new model is built on ResNet50, but it can't tell a dog from an airplane!
#
# It turns out *there are other image classification datasets out there besides ImageNet!* Some of them are specific to things like cancerous cells or handwritten numbers, but we're going to make use of one that's all about **telling different faces apart.**
#
# There are a lot of options for "standard datasets" for training facial recognition systems. Some are based on random faces from the internet (FaceNet and VGGFace), while others are based on *just celebrities* (CelebNet, which seems kind of weird, honestly). There are probably other ones with mug shots and stuff, too.
#
# VGGFace2 is probably the most popular dataset these days, but I couldn't find a pre-trained VGGFace2 model that could easily work with Tensorflow 2! So instead we're going to use [a ResNet50 trained with FaceNet](https://github.com/nyoki-mtl/keras-facenet) by Hiroki Taniai, adapted for Tensorflow 2 by [Rajan Ghimire](https://github.com/R4j4n/Face-recognition-Using-Facenet-On-Tensorflow-2.X).
#
# In short: **we're using some random face-trained model from the internet instead of one trained on ImageNet.**
#
# ## Defining the model
#
# Once upon a time we wrote our own model. It looked something like this:
#
# ```python
# model = tf.keras.Sequential([
#   tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=IMAGE_SHAPE),
#   tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
#   tf.keras.layers.MaxPooling2D(),
#   tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
#   tf.keras.layers.MaxPooling2D(),
#   tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
#   tf.keras.layers.MaxPooling2D(),
#   tf.keras.layers.Dropout(0.2),
#   tf.keras.layers.Flatten(),
#   tf.keras.layers.Dense(128, activation='relu'),
#   tf.keras.layers.Dense(len(class_names), activation='softmax')
# ])
# ```
#
# That was a baby model for little babies. In order to use FaceNet, we need to grow up a little!
#
# Our new model is in the cell below. **Run it.**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Activation, Input, Add, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Concatenate, Lambda, add, GlobalAveragePooling2D, Convolution2D, LocallyConnected2D, ZeroPadding2D, concatenate, AveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K


def scaling(x, scale):
	return x * scale

def InceptionResNetV2():
	inputs = Input(shape=(160, 160, 3))
	x = Conv2D(32, 3, strides=2, padding='valid', use_bias=False, name= 'Conv2d_1a_3x3') (inputs)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_1a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_1a_3x3_Activation')(x)
	x = Conv2D(32, 3, strides=1, padding='valid', use_bias=False, name= 'Conv2d_2a_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_2a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_2a_3x3_Activation')(x)
	x = Conv2D(64, 3, strides=1, padding='same', use_bias=False, name= 'Conv2d_2b_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_2b_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_2b_3x3_Activation')(x)
	x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
	x = Conv2D(80, 1, strides=1, padding='valid', use_bias=False, name= 'Conv2d_3b_1x1') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_3b_1x1_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_3b_1x1_Activation')(x)
	x = Conv2D(192, 3, strides=1, padding='valid', use_bias=False, name= 'Conv2d_4a_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_4a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_4a_3x3_Activation')(x)
	x = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Conv2d_4b_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_4b_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_4b_3x3_Activation')(x)
	
	# 5x Block35 (Inception-ResNet-A block):
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_1_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_1_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_1_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_2_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_2_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_2_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_2_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_3_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_3_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_3_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_3_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_4_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_4_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_4_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_4_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_5_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_5_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_5_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_5_Activation')(x)

	# Mixed 6a (Reduction-A block):
	branch_0 = Conv2D(384, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_6a_Branch_0_Conv2d_1a_3x3') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_0_Conv2d_1a_3x3_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_6a_Branch_0_Conv2d_1a_3x3_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, 3, strides=1, padding='same', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_1 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_1a_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_1a_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_1a_3x3_Activation')(branch_1)
	branch_pool = MaxPooling2D(3, strides=2, padding='valid', name='Mixed_6a_Branch_2_MaxPool_1a_3x3')(x)
	branches = [branch_0, branch_1, branch_pool]
	x = Concatenate(axis=3, name='Mixed_6a')(branches)

	# 10x Block17 (Inception-ResNet-B block):
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_1_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_1_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_2_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_2_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_3_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_3_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_4_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_4_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_5_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_5_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_6_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_6_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_6_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_6_Activation')(x)	
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_7_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_7_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_7_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_7_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_8_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_8_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_8_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_8_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_9_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_9_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_9_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_9_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_10_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_10_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_10_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_10_Activation')(x)

	# Mixed 7a (Reduction-B block): 8 x 8 x 2080	
	branch_0 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_0_Conv2d_0a_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_0_Conv2d_0a_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_7a_Branch_0_Conv2d_0a_1x1_Activation')(branch_0)
	branch_0 = Conv2D(384, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_0_Conv2d_1a_3x3') (branch_0)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_0_Conv2d_1a_3x3_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_7a_Branch_0_Conv2d_1a_3x3_Activation')(branch_0)
	branch_1 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_7a_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_1_Conv2d_1a_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_1_Conv2d_1a_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_7a_Branch_1_Conv2d_1a_3x3_Activation')(branch_1)
	branch_2 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(256, 3, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_1a_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_1a_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_1a_3x3_Activation')(branch_2)
	branch_pool = MaxPooling2D(3, strides=2, padding='valid', name='Mixed_7a_Branch_3_MaxPool_1a_3x3')(x)
	branches = [branch_0, branch_1, branch_2, branch_pool]
	x = Concatenate(axis=3, name='Mixed_7a')(branches)

	# 5x Block8 (Inception-ResNet-C block):
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_1_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_1_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_2_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_2_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_3_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_3_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_4_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_4_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_5_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_5_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_6_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_6_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_6_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 1})(up)
	x = add([x, up])
	
	# Classification block
	x = GlobalAveragePooling2D(name='AvgPool')(x)
	x = Dropout(1.0 - 0.8, name='Dropout')(x)
	# Bottleneck
	x = Dense(128, use_bias=False, name='Bottleneck')(x)
	x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False, name='Bottleneck_BatchNorm')(x)

	# Create model
	model = Model(inputs, x, name='inception_resnet_v1')

	return model

# %% [markdown]
# Fun, right?
#
# To use a pre-trained model, we need two things:
#
# 1. The **model architecture:** what the "magic inside" layers look like, and
# 2. The **model weights:** what the "magic inside" layers learned from training, e.g.
#
# Previously we just pointed Tensorflow at some URL to download all of that info, but now we need to do it manually.
#
# The giant cell above defined the **model architecture** (in this case, ResNet50). Now we need to **give it the pre-trained weights!**
#
# Download `facenet_keras_weights.h5` from CourseWorks or [my Google Drive](https://drive.google.com/file/d/1DCU55aVf93bz7kAYmWrFc1G91-cyf6Js/view?usp=sharing) and upload it to Colab. You should be able to just drag-and-drop into the area to the left of here. You can also upload to Google Drive and use the copy command from up above like we did with `faces.zip` in the very beginning.
#
# After it's done uploading – which might take a while, watch the little circle on the bottom left of the screen – **run the cell below to import the pre-trained weights.**
#
# > If we were very wealthy, had a lot of time, and didn't care about the enviroment, another option would be to download the FaceNet dataset and train our model from scratch. But instead: *we're lazy.*

# %%
# Create the FaceNet model
pretrained_face_model = InceptionResNetV2()

# # Load the weights of the model
pretrained_face_model.load_weights("facenet_keras_weights.h5")
pretrained_face_model.trainable = False

# %% [markdown]
# ## Set up our new model
#
# Now we have our nice new `pretrained_face_encoder`, ready to go!
#
# Last time we built our model, it looked like this:
#
# ```python
# # base_model_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"
# # base_model_url = "https://tfhub.dev/tensorflow/resnet_50/feature_vector/1"
# # base_model_url = "https://tfhub.dev/google/imagenet/resnet_v2_101/feature_vector/5"
#
# # download the model from
# pretrained_model = hub.KerasLayer(base_model_url, trainable=False)
#
# model = tf.keras.Sequential([
#     tf.keras.layers.InputLayer(input_shape=IMAGE_SIZE + (3,)),
#     pretrained_model,
#     tf.keras.layers.Dropout(rate=0.2),
#     tf.keras.layers.Dense(train_generator.num_classes,
#                           activation='softmax')
# ])
# model.build((None,)+IMAGE_SIZE+(3,))
# model.summary()
# ```
#
# **Copy and paste this code into the cell below.**
#
# We'll then need to make **two changes** to use our new model:
#
# 1. Change this code to use the `pretrained_face_model` instead of the model downloaded from tfhub.
# 2. FaceNet didn't use 224x224 images, so we'll need to change `IMAGE_SIZE`. Can you look at the awful, long cell where we defined the architecture to see what the new image size needs to be? *Hint: it's pretty close to the top!*

# %%
# base_model_url = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"
# base_model_url = "https://tfhub.dev/tensorflow/resnet_50/feature_vector/1"
# base_model_url = "https://tfhub.dev/google/imagenet/resnet_v2_101/feature_vector/5"
 
# download the model from 
pretrained_model = pretrained_face_model

#hub.KerasLayer(base_model_url, trainable=False)
 
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(160, 160) + (3,)),
    pretrained_model,
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(train_generator.num_classes,
                          activation='softmax')
])
model.build((None,)+(160, 160)+(3,))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_resnet_v1 (Functio (None, 128)               22808144
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 536)               69144
# =================================================================
# Total params: 22,877,288
# Trainable params: 69,144
# Non-trainable params: 22,808,144
# _________________________________________________________________

# %% [markdown]
# ## Compile and train the model
#
# You can copy and paste the same code from the `model.compile` and `model.fit` cells we used before to train this model.
#
# **How many epochs should you use this time?** Feel free to experiment with different numbers.

# %%
# model.compile code goes here
model.compile(
  optimizer='adam', 
  loss=tf.keras.losses.SparseCategoricalCrossentropy(),
  metrics=['accuracy'])

# %%
# num_epochs/fit/etc code goes here

num_epochs = 50

steps_per_epoch = train_generator.samples // train_generator.batch_size
validation_steps = valid_generator.samples // valid_generator.batch_size
model.fit(
    train_generator,
    epochs=num_epochs,
    steps_per_epoch=steps_per_epoch,
    validation_data=valid_generator,
    validation_steps=validation_steps)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 3s 396ms/step - loss: 1.3358 - accuracy: 0.5972
# Epoch 2/50
# 7/7 [==============================] - 3s 400ms/step - loss: 1.2853 - accuracy: 0.6250
# Epoch 3/50
# 7/7 [==============================] - 3s 378ms/step - loss: 1.2625 - accuracy: 0.6296
# Epoch 4/50
# 7/7 [==============================] - 3s 375ms/step - loss: 1.2214 - accuracy: 0.6343
# Epoch 5/50
# 7/7 [==============================] - 3s 385ms/step - loss: 1.2153 - accuracy: 0.6389
# Epoch 6/50
# 7/7 [==============================] - 3s 390ms/step - loss: 1.1805 - accuracy: 0.6473
# Epoch 7/50
# 7/7 [==============================] - 3s 370ms/step - loss: 1.1739 - accuracy: 0.6111
# Epoch 8/50
# 7/7 [==============================] - 3s 375ms/step - loss: 1.1582 - accuracy: 0.6204
# Epoch 9/50
# 7/7 [==============================] - 3s 405ms/step - loss: 1.1005 - accuracy: 0.6562
# Epoch 10/50
# 7/7 [==============================] - 3s 375ms/step - loss: 1.0873 - accuracy: 0.6713
# Epoch 11/50
# 7/7 [==============================] - 3s 376ms/step - loss: 1.1075 - accuracy: 0.6435
# Epoch 12/50
# 7/7 [==============================] - 3s 390ms/step - loss: 1.1148 - accuracy: 0.6574
# Epoch 13/50
# 7/7 [==============================] - 3s 381ms/step - loss: 1.0856 - accuracy: 0.6574
# Epoch 14/50
# 7/7 [==============================] - 3s 374ms/step - loss: 1.0350 - accuracy: 0.6759
# Epoch 15/50
# 7/7 [==============================] - 3s 373ms/step - loss: 1.0395 - accuracy: 0.6713
# Epoch 16/50
# 7/7 [==============================] - 3s 385ms/step - loss: 1.0393 - accuracy: 0.6713
# Epoch 17/50
# 7/7 [==============================] - 3s 378ms/step - loss: 1.0522 - accuracy: 0.6806
# Epoch 18/50
# 7/7 [==============================] - 3s 377ms/step - loss: 1.0061 - accuracy: 0.6481
# Epoch 19/50
# 7/7 [==============================] - 3s 375ms/step - loss: 1.0060 - accuracy: 0.6898
# Epoch 20/50
# 7/7 [==============================] - 3s 392ms/step - loss: 1.0104 - accuracy: 0.6786
# Epoch 21/50
# 7/7 [==============================] - 3s 372ms/step - loss: 0.9445 - accuracy: 0.6620
# Epoch 22/50
# 7/7 [==============================] - 3s 369ms/step - loss: 0.9789 - accuracy: 0.6481
# Epoch 23/50
# 7/7 [==============================] - 3s 403ms/step - loss: 0.9102 - accuracy: 0.7188
# Epoch 24/50
# 7/7 [==============================] - 3s 376ms/step - loss: 0.9606 - accuracy: 0.6759
# Epoch 25/50
# 7/7 [==============================] - 3s 381ms/step - loss: 0.9795 - accuracy: 0.6944
# Epoch 26/50
# 7/7 [==============================] - 3s 381ms/step - loss: 0.9989 - accuracy: 0.6713
# Epoch 27/50
# 7/7 [==============================] - 3s 376ms/step - loss: 0.9123 - accuracy: 0.6759
# Epoch 28/50
# 7/7 [==============================] - 3s 391ms/step - loss: 0.8779 - accuracy: 0.7098
# Epoch 29/50
# 7/7 [==============================] - 3s 374ms/step - loss: 0.8969 - accuracy: 0.6898
# Epoch 30/50
# 7/7 [==============================] - 3s 390ms/step - loss: 0.9485 - accuracy: 0.6429
# Epoch 31/50
# 7/7 [==============================] - 3s 377ms/step - loss: 0.9652 - accuracy: 0.6759
# Epoch 32/50
# 7/7 [==============================] - 3s 381ms/step - loss: 0.9989 - accuracy: 0.6620
# Epoch 33/50
# 7/7 [==============================] - 3s 385ms/step - loss: 0.8618 - accuracy: 0.7130
# Epoch 34/50
# 7/7 [==============================] - 3s 382ms/step - loss: 0.9571 - accuracy: 0.6620
# Epoch 35/50
# 7/7 [==============================] - 3s 376ms/step - loss: 0.9414 - accuracy: 0.6667
# Epoch 36/50
# 7/7 [==============================] - 3s 393ms/step - loss: 0.9262 - accuracy: 0.6741
# Epoch 37/50
# 7/7 [==============================] - 3s 374ms/step - loss: 0.8566 - accuracy: 0.7176
# Epoch 38/50
# 7/7 [==============================] - 3s 379ms/step - loss: 0.8995 - accuracy: 0.6759
# Epoch 39/50
# 7/7 [==============================] - 3s 373ms/step - loss: 0.8946 - accuracy: 0.6944
# Epoch 40/50
# 7/7 [==============================] - 3s 400ms/step - loss: 0.8863 - accuracy: 0.6852
# Epoch 41/50
# 7/7 [==============================] - 3s 372ms/step - loss: 0.9071 - accuracy: 0.6759
# Epoch 42/50
# 7/7 [==============================] - 3s 390ms/step - loss: 0.8644 - accuracy: 0.6713
# Epoch 43/50
# 7/7 [==============================] - 3s 394ms/step - loss: 0.9085 - accuracy: 0.6713
# Epoch 44/50
# 7/7 [==============================] - 3s 392ms/step - loss: 0.9046 - accuracy: 0.6741
# Epoch 45/50
# 7/7 [==============================] - 3s 379ms/step - loss: 0.8831 - accuracy: 0.7269
# Epoch 46/50
# 7/7 [==============================] - 3s 374ms/step - loss: 0.8827 - accuracy: 0.7037
# Epoch 47/50
# 7/7 [==============================] - 3s 394ms/step - loss: 0.8131 - accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 3s 372ms/step - loss: 0.8845 - accuracy: 0.6852
# Epoch 49/50
# 7/7 [==============================] - 3s 399ms/step - loss: 0.8996 - accuracy: 0.6384
# Epoch 50/50
# 7/7 [==============================] - 3s 378ms/step - loss: 0.8506 - accuracy: 0.6991

# %% [markdown]
# ## How did it do?
#
# Just like we did before, paste the last epoch result below. Be sure to comment it out!

# %%
# Epoch 50/50
# 7/7 [==============================] - 3s 378ms/step - loss: 0.8506 - accuracy: 0.6991
# <tensorflow.python.keras.callbacks.History at 0x7f5cee5f5d90>

# %% [markdown]
# ## Save your model
#
# We'll save this model, too! Our last one was `face_recognition_v1`, so this one can be `face_recognition_v2`.

# %%
# !mkdir -p /content/gdrive/MyDrive/models/face_recognition_v2
model.save('/content/gdrive/MyDrive/models/face_recognition_v2')
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v2/assets
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/models/face_recognition_v2/assets
